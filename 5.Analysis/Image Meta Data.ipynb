# %% [markdown]
# #UPLOAD TO LIGHTLY TO VIEW MATA DATA AND EMBEDDINGS

# %%
# make sure you installed our pip package in your python environment

# !pip install lightly
# Out:
# ...
#      |████████████████████████████████| 325 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 145 kB 70.9 MB/s
# ...
#      |████████████████████████████████| 527 kB 68.7 MB/s
# ...
#      |████████████████████████████████| 74 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 112 kB 80.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 58.2 MB/s
# ...
#      |████████████████████████████████| 829 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 952 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 133 kB 77.3 MB/s
# ...
#      |████████████████████████████████| 396 kB 73.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 51.7 MB/s
# ...
#      |████████████████████████████████| 271 kB 55.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 94 kB 4.2 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # TRAINING SET

# %%
import os
cpt = sum([len(files) for r, d, files in os.walk("/content/drive/MyDrive/SemSeg2/data/leftImg8bit/train")])

# %%
cpt
# Out:
# 2975

# %%
# !lightly-magic token='5a98f017812c7a09b176e64da53eb44d' dataset_id='61f1211ff84837eb446b4457'  input_dir='/content/drive/MyDrive/SemSeg2/data/leftImg8bit/train'  trainer.max_epochs=20
# Out:
# ########## Starting to train an embedding model.
# /usr/local/lib/python3.7/dist-packages/lightly/cli/train_cli.py:70: UserWarning: Training a self-supervised model with a small batch size: 16! Small batch size may harm embedding quality. You can specify the batch size via the loader key-word: loader.batch_size=BSZ
#   warnings.warn(msg)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Missing logger folder: /content/lightly_outputs/2022-01-26/10-31-08/lightning_logs
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | _SimCLR    | 11.2 M
# 1 | criterion | NTXentLoss | 0
# -----------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.762    Total estimated model params size (MB)
# ...

# %% [markdown]
# #VALIDATION SET

# %%
import os
cpt = sum([len(files) for r, d, files in os.walk("/content/drive/MyDrive/SemSeg2/data/leftImg8bit/val")])
cpt
# Out:
# 500

# %%
# !lightly-magic token='5a98f017812c7a09b176e64da53eb44d' dataset_id='61f12f82255144fec99e8f79' input_dir='/content/drive/MyDrive/SemSeg2/data/leftImg8bit/val' trainer.max_epochs=20
# Out:
# ########## Starting to train an embedding model.
# /usr/local/lib/python3.7/dist-packages/lightly/cli/train_cli.py:70: UserWarning: Training a self-supervised model with a small batch size: 16! Small batch size may harm embedding quality. You can specify the batch size via the loader key-word: loader.batch_size=BSZ
#   warnings.warn(msg)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Missing logger folder: /content/lightly_outputs/2022-01-26/12-50-35/lightning_logs
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | _SimCLR    | 11.2 M
# 1 | criterion | NTXentLoss | 0
# -----------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.762    Total estimated model params size (MB)
# ...

# %% [markdown]
# #TEST SET

# %%
import os
cpt = sum([len(files) for r, d, files in os.walk("/content/drive/MyDrive/SemSeg2/data/leftImg8bit/test")])
cpt

# %%
# Recommended: If you have access to a GPU
# you can do additional fine-tuning (for example for 20 epochs)

# !lightly-magic token='5a98f017812c7a09b176e64da53eb44d' dataset_id='61ea8d1d1a1a6cc4422a777f' input_dir='/content/drive/MyDrive/SemSeg2/data/leftImg8bit/test'  trainer.max_epochs=20
# Out:
# ########## Starting to train an embedding model.
# /usr/local/lib/python3.7/dist-packages/lightly/cli/train_cli.py:66: UserWarning: Training a self-supervised model with a small batch size: 16! Small batch size may harm embedding quality. You can specify the batch size via the loader key-word: loader.batch_size=BSZ
#   warnings.warn(msg)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Missing logger folder: /content/lightly_outputs/2022-01-21/10-51-52/lightning_logs
#
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | model     | _SimCLR    | 11.2 M
# 1 | criterion | NTXentLoss | 0
# -----------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.762    Total estimated model params size (MB)
# ...

# %% [markdown]
# #Semantic Segmentation Implementation 1
#
# https://github.com/meetps/pytorch-semseg

# %% [markdown]
# # Artifacts : Directory Packages and Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2")

# %%
#!cp -r '/content/drive/MyDrive/SemSeg2/data_random/leftImg8bit/val' '/content/drive/MyDrive/SemSeg2/data/leftImg8bit'

# %%
#!cp -r '/content/drive/MyDrive/SemSeg2/data_random/gtFine/val' '/content/drive/MyDrive/SemSeg2/data/gtFine'

# %% [markdown]
# matplotlib==2.0.0
# numpy==1.12.1
# scipy==0.19.0
# torch==0.4.1
# torchvision==0.2.0
# tqdm==4.11.2
# pydensecrf
# protobuf
# tensorboardX

# %%
pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org torch===0.4.1.post2 torchvision===0.2.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch===0.4.1.post2
#   Downloading torch-0.4.1.post2-cp37-cp37m-manylinux1_x86_64.whl (519.5 MB)
#      |████████████████████████████████| 519.5 MB 22 kB/s
# Collecting torchvision===0.2.0
#   Downloading torchvision-0.2.0-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.7 MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (1.15.0)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# Successfully installed torch-0.4.1.post2 torchvision-0.2.0

# %%
import torch
torch.__version__
# Out:
# '0.4.1.post2'

# %%
# !pip install numpy==1.15.0
# Out:
# Collecting numpy==1.15.0
#   Downloading numpy-1.15.0-cp37-cp37m-manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 13 kB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# xarray 0.18.2 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# tifffile 2021.11.2 requires numpy>=1.15.1, but you have numpy 1.15.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pywavelets 1.2.0 requires numpy>=1.17.3, but you have numpy 1.15.0 which is incompatible.
# pyerfa 2.0.0.1 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# pyarrow 3.0.0 requires numpy>=1.16.6, but you have numpy 1.15.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# pandas 1.1.5 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# kapre 0.3.6 requires numpy>=1.18.5, but you have numpy 1.15.0 which is incompatible.
# jaxlib 0.1.71+cuda111 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# fbprophet 0.7.1 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# cupy-cuda111 9.4.0 requires numpy<1.24,>=1.17, but you have numpy 1.15.0 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.15.0

# %%
# !pip install numpy==1.12.1
# Out:
# Collecting numpy==1.12.1
#   Downloading numpy-1.12.1.zip (4.8 MB)
#      |████████████████████████████████| 4.8 MB 5.1 MB/s
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.15.0
#     Uninstalling numpy-1.15.0:
#       Successfully uninstalled numpy-1.15.0
#     Running setup.py install for numpy ... error
#   Rolling back uninstall of numpy
#   Moving to /usr/local/bin/conv-template
#    from /tmp/pip-uninstall-9mjdgl4l/conv-template
#   Moving to /usr/local/bin/f2py
#    from /tmp/pip-uninstall-9mjdgl4l/f2py
#   Moving to /usr/local/bin/from-template
#    from /tmp/pip-uninstall-9mjdgl4l/from-template
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy-1.15.0.dist-info/
#    from /usr/local/lib/python3.7/dist-packages/~umpy-1.15.0.dist-info
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy/
#    from /usr/local/lib/python3.7/dist-packages/~umpy
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-w4ls9l9g/numpy_093b83bbc97342c2889411c064496c36/setup.py'"'"'; __file__='"'"'/tmp/pip-install-w4ls9l9g/numpy_093b83bbc97342c2889411c064496c36/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-fsk9rui5/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/numpy Check the logs for full command output.

# %%
# !pip install matplotlib==2.0.0
# Out:
# Collecting matplotlib==2.0.0
#   Downloading matplotlib-2.0.0.tar.gz (53.2 MB)
#      |████████████████████████████████| 53.2 MB 161 kB/s
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (1.15.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (2018.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (0.11.0)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (3.0.6)
# Building wheels for collected packages: matplotlib
#   Building wheel for matplotlib (setup.py) ... done
#   Created wheel for matplotlib: filename=matplotlib-2.0.0-cp37-cp37m-linux_x86_64.whl size=10703494 sha256=0be465f1cb6dd8829ea18adec05cc67593cf6ed39110db466a419761d95a3215
#   Stored in directory: /root/.cache/pip/wheels/4c/b4/87/9b99b67a71111498af7c91a7bdd0e252112b2be41fd8873575
# Successfully built matplotlib
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires matplotlib!=3.0.0,>=2.0.2, but you have matplotlib 2.0.0 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# seaborn 0.11.2 requires matplotlib>=2.2, but you have matplotlib 2.0.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pycocotools 2.0.4 requires matplotlib>=2.1.0, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# mizani 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# fbprophet 0.7.1 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# arviz 0.11.4 requires matplotlib>=3.0, but you have matplotlib 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed matplotlib-2.0.0

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 47.9 MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.15.0)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires matplotlib!=3.0.0,>=2.0.2, but you have matplotlib 2.0.0 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# seaborn 0.11.2 requires matplotlib>=2.2, but you have matplotlib 2.0.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# kapre 0.3.6 requires numpy>=1.18.5, but you have numpy 1.15.0 which is incompatible.
# jaxlib 0.1.71+cuda111 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# arviz 0.11.4 requires matplotlib>=3.0, but you have matplotlib 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.1.0

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 5.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.4.1

# %% [markdown]
# # One Time

# %%
# !git clone https://github.com/meetps/pytorch-semseg.git

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=Emile87&password=Evangelos71!&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Out:
# --2021-11-01 16:55:09--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2021-11-01 16:55:10--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ]  47.36K  --.-KB/s    in 0.1s
#
# 2021-11-01 16:55:11 (373 KB/s) - ‘index.html’ saved [48495]
#
# --2021-11-01 16:55:11--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252567705 (241M) [application/octet-stream]
# Saving to: ‘gtFine_trainvaltest.zip’
#
# gtFine_trainvaltest 100%[===================>] 240.87M  24.8MB/s    in 11s
#
# 2021-11-01 16:55:22 (22.4 MB/s) - ‘gtFine_trainvaltest.zip’ saved [252567705/252567705]

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=Emile87&password=Evangelos71!&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2021-11-01 16:56:35--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2021-11-01 16:56:36--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.3’
#
# index.html.3            [ <=>                ]  47.36K  --.-KB/s    in 0.1s
#
# 2021-11-01 16:56:36 (378 KB/s) - ‘index.html.3’ saved [48495]
#
# --2021-11-01 16:56:36--  https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11592327197 (11G) [application/octet-stream]
# Saving to: ‘leftImg8bit_trainvaltest.zip’
#
# leftImg8bit_trainva 100%[===================>]  10.80G  20.1MB/s    in 9m 42s
#
# 2021-11-01 17:06:19 (19.0 MB/s) - ‘leftImg8bit_trainvaltest.zip’ saved [11592327197/11592327197]

# %%
# !mkdir data

# %%
# !unzip leftImg8bit_trainvaltest.zip -d data
# !unzip gtFine_trainvaltest.zip -d data

# %% [markdown]
#  self.class_names = [
#             0 "unlabelled",
#             1 "road",
#             2 "sidewalk",
#             3 "building",
#             4 "wall",
#             5 "fence",
#             6 "pole",
#             7 "traffic_light",
#             8 "traffic_sign",
#             9 "vegetation",
#             10 "terrain",
#             11 "sky",
#             12 "person",
#             13"rider",
#             14 "car",
#             15 "truck",
#             16 "bus",
#             17 "train",
#             18 "motorcycle",
#             19 "bicycle",
#         ]

# %% [markdown]
# # Load Config File

# %%
cd pytorch-semseg
# Out:
# [Errno 2] No such file or directory: 'pytorch-semseg'
# /content

# %%
#edit config file

# !ls /content/drive/MyDrive/SemSeg2/data
# Out:
# gtFine	leftImg8bit  license.txt  README

# %% [markdown]
# # Train Model

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2/pytorch-semseg/")

# %%
# N=100 Diverse 
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/29571
# Found 100 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f5f63b6fc20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# 1it [00:39, 39.58s/it]WARN: resizing labels yielded fewer classes
# 63it [01:03,  1.01s/it]
# INFO:ptsemseg:Iter 337 Loss: 0.6481
# Overall Acc: 	 0.8077272192690123
# INFO:ptsemseg:Overall Acc: 	: 0.8077272192690123
# Mean Acc : 	 0.3248066178635198
# INFO:ptsemseg:Mean Acc : 	: 0.3248066178635198
# FreqW Acc : 	 0.6961219208738424
# INFO:ptsemseg:FreqW Acc : 	: 0.6961219208738424
# Mean IoU : 	 0.2605386439736423
# INFO:ptsemseg:Mean IoU : 	: 0.2605386439736423
# INFO:ptsemseg:0: 0.8853412668370118
# INFO:ptsemseg:1: 0.4098214044699612
# INFO:ptsemseg:2: 0.6571194282084489
# INFO:ptsemseg:3: 0.10106702993880438
# INFO:ptsemseg:4: 0.02317988475096583
# INFO:ptsemseg:5: 0.0627499927557774
# INFO:ptsemseg:6: 0.002297031065839621
# INFO:ptsemseg:7: 0.03005170856306264
# INFO:ptsemseg:8: 0.7068101839234469
# INFO:ptsemseg:9: 0.2694738031796481
# INFO:ptsemseg:10: 0.8009335697024219
# INFO:ptsemseg:11: 0.2028766843723125
# INFO:ptsemseg:12: 0.000506976968760562
# INFO:ptsemseg:13: 0.6021425700066909
# INFO:ptsemseg:14: 0.0
# INFO:ptsemseg:15: 0.008572819423682522
# INFO:ptsemseg:16: 0.0036350515188367837
# INFO:ptsemseg:17: 0.02619250796746835
# INFO:ptsemseg:18: 0.15746232184606443

# %%
# N=200
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/95540
# Found 200 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f45e2c17c20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:04,  1.03s/it]
# INFO:ptsemseg:Iter 675 Loss: 0.5626
# Overall Acc: 	 0.8393276574848684
# INFO:ptsemseg:Overall Acc: 	: 0.8393276574848684
# Mean Acc : 	 0.35879881509005124
# INFO:ptsemseg:Mean Acc : 	: 0.35879881509005124
# FreqW Acc : 	 0.7401721955570892
# INFO:ptsemseg:FreqW Acc : 	: 0.7401721955570892
# Mean IoU : 	 0.2999622725478221
# INFO:ptsemseg:Mean IoU : 	: 0.2999622725478221
# INFO:ptsemseg:0: 0.9103264507907006
# INFO:ptsemseg:1: 0.49771946048901794
# INFO:ptsemseg:2: 0.7119523176085323
# INFO:ptsemseg:3: 0.10104196569683625
# INFO:ptsemseg:4: 0.08839313278785078
# INFO:ptsemseg:5: 0.14495085571410096
# INFO:ptsemseg:6: 0.0177376228349541
# INFO:ptsemseg:7: 0.12277633589637858
# INFO:ptsemseg:8: 0.7623724307235064
# INFO:ptsemseg:9: 0.25195677314467363
# INFO:ptsemseg:10: 0.8451149893188618
# INFO:ptsemseg:11: 0.2804880420675925
# INFO:ptsemseg:12: 0.00015359120488258357
# INFO:ptsemseg:13: 0.6449248048987306
# INFO:ptsemseg:14: 0.01937312385073579
# INFO:ptsemseg:15: 2.241840820334393e-05
# INFO:ptsemseg:16: 9.300451071876987e-05
# INFO:ptsemseg:17: 0.047658674433522306
# INFO:ptsemseg:18: 0.25222718402882016

# %%
# N=500

# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/58025
# Found 500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7fb97bfa3c20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/1687]  Loss: 0.3463  Time/Image: 0.1278
# INFO:ptsemseg:Iter [1000/1687]  Loss: 0.3463  Time/Image: 0.1278
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 1it [00:39, 39.18s/it]WARN: resizing labels yielded fewer classes
# 63it [01:04,  1.02s/it]
# INFO:ptsemseg:Iter 1687 Loss: 0.4010
# Overall Acc: 	 0.8838871333593075
# INFO:ptsemseg:Overall Acc: 	: 0.8838871333593075
# Mean Acc : 	 0.4702524738325161
# INFO:ptsemseg:Mean Acc : 	: 0.4702524738325161
# FreqW Acc : 	 0.8051955083324009
# INFO:ptsemseg:FreqW Acc : 	: 0.8051955083324009
# Mean IoU : 	 0.39179866662269847
# INFO:ptsemseg:Mean IoU : 	: 0.39179866662269847
# INFO:ptsemseg:0: 0.9388803935254905
# INFO:ptsemseg:1: 0.6022408628607575
# INFO:ptsemseg:2: 0.7884418389928305
# INFO:ptsemseg:3: 0.18960294365808786
# INFO:ptsemseg:4: 0.14682165192405205
# INFO:ptsemseg:5: 0.2851656849781624
# INFO:ptsemseg:6: 0.07791248389135591
# INFO:ptsemseg:7: 0.27498171146096206
# INFO:ptsemseg:8: 0.8350547889071911
# INFO:ptsemseg:9: 0.40899678800003186
# INFO:ptsemseg:10: 0.8677773054462464
# INFO:ptsemseg:11: 0.4344996433669525
# INFO:ptsemseg:12: 0.030651761496370392
# INFO:ptsemseg:13: 0.7782830171785023
# INFO:ptsemseg:14: 0.03648172599960235
# INFO:ptsemseg:15: 0.21945182565327556
# INFO:ptsemseg:16: 0.05132774906433791
# INFO:ptsemseg:17: 0.06719327663185115
# INFO:ptsemseg:18: 0.4104092127952113

# %%
# N=1000
# ITERS 3365
# 
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/77102
# Found 1000 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7fe35b736dd0>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [100/3365]  Loss: 0.7467  Time/Image: 0.1348
# INFO:ptsemseg:Iter [100/3365]  Loss: 0.7467  Time/Image: 0.1348
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [200/3365]  Loss: 0.5430  Time/Image: 0.1370
# INFO:ptsemseg:Iter [200/3365]  Loss: 0.5430  Time/Image: 0.1370
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [300/3365]  Loss: 0.6092  Time/Image: 0.1364
# INFO:ptsemseg:Iter [300/3365]  Loss: 0.6092  Time/Image: 0.1364
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [400/3365]  Loss: 0.4719  Time/Image: 0.1352
# INFO:ptsemseg:Iter [400/3365]  Loss: 0.4719  Time/Image: 0.1352
# WARN: resizing labels yielded fewer classes
# Iter [500/3365]  Loss: 0.4713  Time/Image: 0.1283
# INFO:ptsemseg:Iter [500/3365]  Loss: 0.4713  Time/Image: 0.1283
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:06,  1.06s/it]
# INFO:ptsemseg:Iter 500 Loss: 0.5114
# Overall Acc: 	 0.8482949671505323
# INFO:ptsemseg:Overall Acc: 	: 0.8482949671505323
# Mean Acc : 	 0.3389478211145891
# INFO:ptsemseg:Mean Acc : 	: 0.3389478211145891
# FreqW Acc : 	 0.7461195869571822
# INFO:ptsemseg:FreqW Acc : 	: 0.7461195869571822
# Mean IoU : 	 0.2832150695790733
# INFO:ptsemseg:Mean IoU : 	: 0.2832150695790733
# INFO:ptsemseg:0: 0.9152872334772891
# INFO:ptsemseg:1: 0.4795814258597588
# INFO:ptsemseg:2: 0.7283359708859597
# INFO:ptsemseg:3: 0.05600734217802458
# INFO:ptsemseg:4: 0.030112516311741677
# INFO:ptsemseg:5: 0.10773506872118647
# INFO:ptsemseg:6: 0.0
# INFO:ptsemseg:7: 0.03850320860071672
# INFO:ptsemseg:8: 0.7799998276426687
# INFO:ptsemseg:9: 0.34165482575977735
# INFO:ptsemseg:10: 0.8130805969022247
# INFO:ptsemseg:11: 0.23790749305822156
# INFO:ptsemseg:12: 0.0
# INFO:ptsemseg:13: 0.673548153687737
# INFO:ptsemseg:14: 0.0
# INFO:ptsemseg:15: 0.0
# INFO:ptsemseg:16: 0.0
# INFO:ptsemseg:17: 0.0
# INFO:ptsemseg:18: 0.1793326589170861
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [600/3365]  Loss: 0.4327  Time/Image: 0.1375
# INFO:ptsemseg:Iter [600/3365]  Loss: 0.4327  Time/Image: 0.1375
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [700/3365]  Loss: 0.4021  Time/Image: 0.1369
# INFO:ptsemseg:Iter [700/3365]  Loss: 0.4021  Time/Image: 0.1369
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [800/3365]  Loss: 0.4357  Time/Image: 0.1382
# INFO:ptsemseg:Iter [800/3365]  Loss: 0.4357  Time/Image: 0.1382
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [900/3365]  Loss: 0.3629  Time/Image: 0.1367
# INFO:ptsemseg:Iter [900/3365]  Loss: 0.3629  Time/Image: 0.1367
# Iter [1000/3365]  Loss: 0.3285  Time/Image: 0.1289
# INFO:ptsemseg:Iter [1000/3365]  Loss: 0.3285  Time/Image: 0.1289
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:58,  1.08it/s]
# INFO:ptsemseg:Iter 1000 Loss: 0.4280
# Overall Acc: 	 0.8677666619010275
# INFO:ptsemseg:Overall Acc: 	: 0.8677666619010275
# Mean Acc : 	 0.39750848811373735
# INFO:ptsemseg:Mean Acc : 	: 0.39750848811373735
# FreqW Acc : 	 0.7801032748222405
# INFO:ptsemseg:FreqW Acc : 	: 0.7801032748222405
# Mean IoU : 	 0.32831987008493596
# INFO:ptsemseg:Mean IoU : 	: 0.32831987008493596
# INFO:ptsemseg:0: 0.9310606567614537
# INFO:ptsemseg:1: 0.5374071875275304
# INFO:ptsemseg:2: 0.7738788374201876
# INFO:ptsemseg:3: 0.13162420206911732
# INFO:ptsemseg:4: 0.11299437428227141
# INFO:ptsemseg:5: 0.15154312495950048
# INFO:ptsemseg:6: 0.011592220410024378
# INFO:ptsemseg:7: 0.166320267557344
# INFO:ptsemseg:8: 0.8066539222466769
# INFO:ptsemseg:9: 0.30839191678123945
# INFO:ptsemseg:10: 0.8494982104183175
# INFO:ptsemseg:11: 0.3435246245660161
# INFO:ptsemseg:12: 1.618437237003949e-05
# INFO:ptsemseg:13: 0.7345864707668679
# INFO:ptsemseg:14: 0.013649052101588679
# INFO:ptsemseg:15: 0.0024033503421187147
# INFO:ptsemseg:16: 0.00904618527877843
# INFO:ptsemseg:17: 0.005795964614110777
# INFO:ptsemseg:18: 0.34809077913826963
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1100/3365]  Loss: 0.2817  Time/Image: 0.1378
# INFO:ptsemseg:Iter [1100/3365]  Loss: 0.2817  Time/Image: 0.1378
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1200/3365]  Loss: 0.3634  Time/Image: 0.1381
# INFO:ptsemseg:Iter [1200/3365]  Loss: 0.3634  Time/Image: 0.1381
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1300/3365]  Loss: 0.3409  Time/Image: 0.1371
# INFO:ptsemseg:Iter [1300/3365]  Loss: 0.3409  Time/Image: 0.1371
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1400/3365]  Loss: 0.3245  Time/Image: 0.1357
# INFO:ptsemseg:Iter [1400/3365]  Loss: 0.3245  Time/Image: 0.1357
# Iter [1500/3365]  Loss: 0.4564  Time/Image: 0.1293
# INFO:ptsemseg:Iter [1500/3365]  Loss: 0.4564  Time/Image: 0.1293
# 1it [00:34, 34.60s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.12it/s]
# INFO:ptsemseg:Iter 1500 Loss: 0.4182
# Overall Acc: 	 0.8718634569110966
# INFO:ptsemseg:Overall Acc: 	: 0.8718634569110966
# Mean Acc : 	 0.42819423992666295
# INFO:ptsemseg:Mean Acc : 	: 0.42819423992666295
# FreqW Acc : 	 0.7866116028075304
# INFO:ptsemseg:FreqW Acc : 	: 0.7866116028075304
# Mean IoU : 	 0.3579842638307376
# INFO:ptsemseg:Mean IoU : 	: 0.3579842638307376
# INFO:ptsemseg:0: 0.9377631361084747
# INFO:ptsemseg:1: 0.5762288767988183
# INFO:ptsemseg:2: 0.7689741828802987
# INFO:ptsemseg:3: 0.12322082857432265
# INFO:ptsemseg:4: 0.18496226590887915
# INFO:ptsemseg:5: 0.22170527164851797
# INFO:ptsemseg:6: 0.05953587396210347
# INFO:ptsemseg:7: 0.15670206517930738
# INFO:ptsemseg:8: 0.7896957550022133
# INFO:ptsemseg:9: 0.2683813622754491
# INFO:ptsemseg:10: 0.8802225476817868
# INFO:ptsemseg:11: 0.40619844161280333
# INFO:ptsemseg:12: 0.02628313505296955
# INFO:ptsemseg:13: 0.7638796701804209
# INFO:ptsemseg:14: 0.12016644833166372
# INFO:ptsemseg:15: 0.029610580777436554
# INFO:ptsemseg:16: 0.03534311728922232
# INFO:ptsemseg:17: 0.05854616174959636
# INFO:ptsemseg:18: 0.3942812917697307
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1600/3365]  Loss: 0.3180  Time/Image: 0.1377
# INFO:ptsemseg:Iter [1600/3365]  Loss: 0.3180  Time/Image: 0.1377
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1700/3365]  Loss: 0.2558  Time/Image: 0.1375
# INFO:ptsemseg:Iter [1700/3365]  Loss: 0.2558  Time/Image: 0.1375
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1800/3365]  Loss: 0.2692  Time/Image: 0.1374
# INFO:ptsemseg:Iter [1800/3365]  Loss: 0.2692  Time/Image: 0.1374
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1900/3365]  Loss: 0.3167  Time/Image: 0.1365
# INFO:ptsemseg:Iter [1900/3365]  Loss: 0.3167  Time/Image: 0.1365
# Iter [2000/3365]  Loss: 0.2703  Time/Image: 0.1288
# INFO:ptsemseg:Iter [2000/3365]  Loss: 0.2703  Time/Image: 0.1288
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 2000 Loss: 0.3701
# Overall Acc: 	 0.8874633833084461
# INFO:ptsemseg:Overall Acc: 	: 0.8874633833084461
# Mean Acc : 	 0.46880334707112736
# INFO:ptsemseg:Mean Acc : 	: 0.46880334707112736
# FreqW Acc : 	 0.8070391394526046
# INFO:ptsemseg:FreqW Acc : 	: 0.8070391394526046
# Mean IoU : 	 0.38719627812900476
# INFO:ptsemseg:Mean IoU : 	: 0.38719627812900476
# INFO:ptsemseg:0: 0.9350459718073796
# INFO:ptsemseg:1: 0.5527002127362668
# INFO:ptsemseg:2: 0.8045892723676557
# INFO:ptsemseg:3: 0.20472325364384325
# INFO:ptsemseg:4: 0.1449591665664209
# INFO:ptsemseg:5: 0.2523456764324821
# INFO:ptsemseg:6: 0.026320868939619928
# INFO:ptsemseg:7: 0.23238215742096216
# INFO:ptsemseg:8: 0.8514019798029892
# INFO:ptsemseg:9: 0.4397117321039229
# INFO:ptsemseg:10: 0.8727339018697509
# INFO:ptsemseg:11: 0.41658359145986873
# INFO:ptsemseg:12: 0.0031045382704899525
# INFO:ptsemseg:13: 0.7820178339316294
# INFO:ptsemseg:14: 0.14254984571564205
# INFO:ptsemseg:15: 0.10079484489510959
# INFO:ptsemseg:16: 0.12472333230863818
# INFO:ptsemseg:17: 0.050242178815308874
# INFO:ptsemseg:18: 0.41979892536310975
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2100/3365]  Loss: 0.2315  Time/Image: 0.1369
# INFO:ptsemseg:Iter [2100/3365]  Loss: 0.2315  Time/Image: 0.1369
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2200/3365]  Loss: 0.2995  Time/Image: 0.1355
# INFO:ptsemseg:Iter [2200/3365]  Loss: 0.2995  Time/Image: 0.1355
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2300/3365]  Loss: 0.2086  Time/Image: 0.1368
# INFO:ptsemseg:Iter [2300/3365]  Loss: 0.2086  Time/Image: 0.1368
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2400/3365]  Loss: 0.1836  Time/Image: 0.1360
# INFO:ptsemseg:Iter [2400/3365]  Loss: 0.1836  Time/Image: 0.1360
# Iter [2500/3365]  Loss: 0.1739  Time/Image: 0.1282
# INFO:ptsemseg:Iter [2500/3365]  Loss: 0.1739  Time/Image: 0.1282
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:55,  1.13it/s]
# INFO:ptsemseg:Iter 2500 Loss: 0.3506
# Overall Acc: 	 0.8941922011567962
# INFO:ptsemseg:Overall Acc: 	: 0.8941922011567962
# Mean Acc : 	 0.5237149082476603
# INFO:ptsemseg:Mean Acc : 	: 0.5237149082476603
# FreqW Acc : 	 0.8237382962690599
# INFO:ptsemseg:FreqW Acc : 	: 0.8237382962690599
# Mean IoU : 	 0.425779041245655
# INFO:ptsemseg:Mean IoU : 	: 0.425779041245655
# INFO:ptsemseg:0: 0.9508970869175197
# INFO:ptsemseg:1: 0.6569994168262635
# INFO:ptsemseg:2: 0.810580836757861
# INFO:ptsemseg:3: 0.15972901784685276
# INFO:ptsemseg:4: 0.2429912969662195
# INFO:ptsemseg:5: 0.3145950864241038
# INFO:ptsemseg:6: 0.17454401268834258
# INFO:ptsemseg:7: 0.3445604633752315
# INFO:ptsemseg:8: 0.8412978381494476
# INFO:ptsemseg:9: 0.45625484352127815
# INFO:ptsemseg:10: 0.8757468189184463
# INFO:ptsemseg:11: 0.47157939106075614
# INFO:ptsemseg:12: 0.1102926116580417
# INFO:ptsemseg:13: 0.8034812890638293
# INFO:ptsemseg:14: 0.0882419206575224
# INFO:ptsemseg:15: 0.20826613327718707
# INFO:ptsemseg:16: 0.0662303859596936
# INFO:ptsemseg:17: 0.047617288511267085
# INFO:ptsemseg:18: 0.4658960450875816
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2600/3365]  Loss: 0.2189  Time/Image: 0.1370
# INFO:ptsemseg:Iter [2600/3365]  Loss: 0.2189  Time/Image: 0.1370
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2700/3365]  Loss: 0.1307  Time/Image: 0.1371
# INFO:ptsemseg:Iter [2700/3365]  Loss: 0.1307  Time/Image: 0.1371
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2800/3365]  Loss: 0.1754  Time/Image: 0.1367
# INFO:ptsemseg:Iter [2800/3365]  Loss: 0.1754  Time/Image: 0.1367
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2900/3365]  Loss: 0.1792  Time/Image: 0.1354
# INFO:ptsemseg:Iter [2900/3365]  Loss: 0.1792  Time/Image: 0.1354
# Iter [3000/3365]  Loss: 0.1451  Time/Image: 0.1286
# INFO:ptsemseg:Iter [3000/3365]  Loss: 0.1451  Time/Image: 0.1286
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 3000 Loss: 0.3181
# Overall Acc: 	 0.9047244728952178
# INFO:ptsemseg:Overall Acc: 	: 0.9047244728952178
# Mean Acc : 	 0.5472028037263553
# INFO:ptsemseg:Mean Acc : 	: 0.5472028037263553
# FreqW Acc : 	 0.8396531528835779
# INFO:ptsemseg:FreqW Acc : 	: 0.8396531528835779
# Mean IoU : 	 0.4507251295041101
# INFO:ptsemseg:Mean IoU : 	: 0.4507251295041101
# INFO:ptsemseg:0: 0.9568293995425128
# INFO:ptsemseg:1: 0.679338139016266
# INFO:ptsemseg:2: 0.8337452633052381
# INFO:ptsemseg:3: 0.23202903978758552
# INFO:ptsemseg:4: 0.20502600745724028
# INFO:ptsemseg:5: 0.37065738709161516
# INFO:ptsemseg:6: 0.24156128723642284
# INFO:ptsemseg:7: 0.36247072879330944
# INFO:ptsemseg:8: 0.8609430381614201
# INFO:ptsemseg:9: 0.44383924590129936
# INFO:ptsemseg:10: 0.9013228528081851
# INFO:ptsemseg:11: 0.519571910683741
# INFO:ptsemseg:12: 0.06477177883106044
# INFO:ptsemseg:13: 0.8226309050238232
# INFO:ptsemseg:14: 0.11759930198160704
# INFO:ptsemseg:15: 0.2887529531391541
# INFO:ptsemseg:16: 0.15542682260356322
# INFO:ptsemseg:17: 0.09421310720381458
# INFO:ptsemseg:18: 0.41304829201023413
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3100/3365]  Loss: 0.1624  Time/Image: 0.1373
# INFO:ptsemseg:Iter [3100/3365]  Loss: 0.1624  Time/Image: 0.1373
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3200/3365]  Loss: 0.1336  Time/Image: 0.1368
# INFO:ptsemseg:Iter [3200/3365]  Loss: 0.1336  Time/Image: 0.1368
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3300/3365]  Loss: 0.1473  Time/Image: 0.1364
# INFO:ptsemseg:Iter [3300/3365]  Loss: 0.1473  Time/Image: 0.1364
# 2it [00:35, 14.60s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 3365 Loss: 0.3327
# Overall Acc: 	 0.9024422089601821
# INFO:ptsemseg:Overall Acc: 	: 0.9024422089601821
# Mean Acc : 	 0.5555806869168631
# INFO:ptsemseg:Mean Acc : 	: 0.5555806869168631
# FreqW Acc : 	 0.8370473331442613
# INFO:ptsemseg:FreqW Acc : 	: 0.8370473331442613
# Mean IoU : 	 0.4602289386278855
# INFO:ptsemseg:Mean IoU : 	: 0.4602289386278855
# INFO:ptsemseg:0: 0.9541664722905515
# INFO:ptsemseg:1: 0.6319078118248596
# INFO:ptsemseg:2: 0.8337853007508599
# INFO:ptsemseg:3: 0.220908129159519
# INFO:ptsemseg:4: 0.21386207842584373
# INFO:ptsemseg:5: 0.2871708244095201
# INFO:ptsemseg:6: 0.23109736359385677
# INFO:ptsemseg:7: 0.3574298786552616
# INFO:ptsemseg:8: 0.865255096638356
# INFO:ptsemseg:9: 0.45519960741435866
# INFO:ptsemseg:10: 0.8841300831515857
# INFO:ptsemseg:11: 0.5016753376515987
# INFO:ptsemseg:12: 0.22833276164726296
# INFO:ptsemseg:13: 0.8384038275982717
# INFO:ptsemseg:14: 0.19830183806121132
# INFO:ptsemseg:15: 0.3145862004381072
# INFO:ptsemseg:16: 0.15575961321438328
# INFO:ptsemseg:17: 0.08897319587628866
# INFO:ptsemseg:18: 0.48340441312812904
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fe35d13b7a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.7/dist-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 498, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 747, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
# N=1500
#5062
#
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/61725
# Found 1500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f66dabdbc20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [100/5062]  Loss: 0.7195  Time/Image: 0.1404
# INFO:ptsemseg:Iter [100/5062]  Loss: 0.7195  Time/Image: 0.1404
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [200/5062]  Loss: 0.5070  Time/Image: 0.1309
# INFO:ptsemseg:Iter [200/5062]  Loss: 0.5070  Time/Image: 0.1309
# WARN: resizing labels yielded fewer classes
# Iter [300/5062]  Loss: 0.5382  Time/Image: 0.1393
# INFO:ptsemseg:Iter [300/5062]  Loss: 0.5382  Time/Image: 0.1393
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [400/5062]  Loss: 0.5459  Time/Image: 0.1345
# INFO:ptsemseg:Iter [400/5062]  Loss: 0.5459  Time/Image: 0.1345
# WARN: resizing labels yielded fewer classes
# Iter [500/5062]  Loss: 0.3346  Time/Image: 0.1334
# INFO:ptsemseg:Iter [500/5062]  Loss: 0.3346  Time/Image: 0.1334
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:58,  1.07it/s]
# INFO:ptsemseg:Iter 500 Loss: 0.5152
# Overall Acc: 	 0.8447069250311996
# INFO:ptsemseg:Overall Acc: 	: 0.8447069250311996
# Mean Acc : 	 0.32314471940124767
# INFO:ptsemseg:Mean Acc : 	: 0.32314471940124767
# FreqW Acc : 	 0.7332452059899605
# INFO:ptsemseg:FreqW Acc : 	: 0.7332452059899605
# Mean IoU : 	 0.2698385566596015
# INFO:ptsemseg:Mean IoU : 	: 0.2698385566596015
# INFO:ptsemseg:0: 0.9057631202780168
# INFO:ptsemseg:1: 0.4216936433084632
# INFO:ptsemseg:2: 0.7219701977769185
# INFO:ptsemseg:3: 0.017483710613808972
# INFO:ptsemseg:4: 0.00822655869223412
# INFO:ptsemseg:5: 0.16819430689581108
# INFO:ptsemseg:6: 0.000970534231004634
# INFO:ptsemseg:7: 0.04419281010865292
# INFO:ptsemseg:8: 0.7751478662416522
# INFO:ptsemseg:9: 0.32097520143037017
# INFO:ptsemseg:10: 0.762228812159464
# INFO:ptsemseg:11: 0.15946908033498233
# INFO:ptsemseg:12: 0.0
# INFO:ptsemseg:13: 0.6517719035940271
# INFO:ptsemseg:14: 0.0
# INFO:ptsemseg:15: 0.00020627062706270627
# INFO:ptsemseg:16: 0.0
# INFO:ptsemseg:17: 0.0
# INFO:ptsemseg:18: 0.16863856023996002
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [600/5062]  Loss: 0.5491  Time/Image: 0.1384
# INFO:ptsemseg:Iter [600/5062]  Loss: 0.5491  Time/Image: 0.1384
# WARN: resizing labels yielded fewer classes
# Iter [700/5062]  Loss: 0.3708  Time/Image: 0.1315
# INFO:ptsemseg:Iter [700/5062]  Loss: 0.3708  Time/Image: 0.1315
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [800/5062]  Loss: 0.5486  Time/Image: 0.1403
# INFO:ptsemseg:Iter [800/5062]  Loss: 0.5486  Time/Image: 0.1403
# WARN: resizing labels yielded fewer classes
# Iter [900/5062]  Loss: 0.4452  Time/Image: 0.1292
# INFO:ptsemseg:Iter [900/5062]  Loss: 0.4452  Time/Image: 0.1292
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/5062]  Loss: 0.3969  Time/Image: 0.1414
# INFO:ptsemseg:Iter [1000/5062]  Loss: 0.3969  Time/Image: 0.1414
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.09it/s]
# INFO:ptsemseg:Iter 1000 Loss: 0.4436
# Overall Acc: 	 0.862618569661662
# INFO:ptsemseg:Overall Acc: 	: 0.862618569661662
# Mean Acc : 	 0.3961153185681889
# INFO:ptsemseg:Mean Acc : 	: 0.3961153185681889
# FreqW Acc : 	 0.7713412090635486
# INFO:ptsemseg:FreqW Acc : 	: 0.7713412090635486
# Mean IoU : 	 0.32836664510530084
# INFO:ptsemseg:Mean IoU : 	: 0.32836664510530084
# INFO:ptsemseg:0: 0.9331535033750415
# INFO:ptsemseg:1: 0.5452568338194224
# INFO:ptsemseg:2: 0.7345542327129729
# INFO:ptsemseg:3: 0.0410569567092688
# INFO:ptsemseg:4: 0.0717802714368987
# INFO:ptsemseg:5: 0.24831563941162774
# INFO:ptsemseg:6: 0.01413572343149808
# INFO:ptsemseg:7: 0.12811926136887453
# INFO:ptsemseg:8: 0.7913411267052802
# INFO:ptsemseg:9: 0.37846791399678736
# INFO:ptsemseg:10: 0.8668943828136373
# INFO:ptsemseg:11: 0.36147397338132903
# INFO:ptsemseg:12: 0.00021021142418239884
# INFO:ptsemseg:13: 0.7348280130528777
# INFO:ptsemseg:14: 5.789214693026891e-06
# INFO:ptsemseg:15: 0.04869852158999631
# INFO:ptsemseg:16: 0.05219167795076781
# INFO:ptsemseg:17: 0.008139990423540678
# INFO:ptsemseg:18: 0.2803422341820189
# Iter [1100/5062]  Loss: 0.3936  Time/Image: 0.1275
# INFO:ptsemseg:Iter [1100/5062]  Loss: 0.3936  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1200/5062]  Loss: 0.2907  Time/Image: 0.1428
# INFO:ptsemseg:Iter [1200/5062]  Loss: 0.2907  Time/Image: 0.1428
# Iter [1300/5062]  Loss: 0.4259  Time/Image: 0.1275
# INFO:ptsemseg:Iter [1300/5062]  Loss: 0.4259  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1400/5062]  Loss: 0.4006  Time/Image: 0.1423
# INFO:ptsemseg:Iter [1400/5062]  Loss: 0.4006  Time/Image: 0.1423
# Iter [1500/5062]  Loss: 0.5480  Time/Image: 0.1275
# INFO:ptsemseg:Iter [1500/5062]  Loss: 0.5480  Time/Image: 0.1275
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 1500 Loss: 0.4122
# Overall Acc: 	 0.8713646324354423
# INFO:ptsemseg:Overall Acc: 	: 0.8713646324354423
# Mean Acc : 	 0.43094690600821073
# INFO:ptsemseg:Mean Acc : 	: 0.43094690600821073
# FreqW Acc : 	 0.7835184421236783
# INFO:ptsemseg:FreqW Acc : 	: 0.7835184421236783
# Mean IoU : 	 0.34913264460566534
# INFO:ptsemseg:Mean IoU : 	: 0.34913264460566534
# INFO:ptsemseg:0: 0.9284300036707792
# INFO:ptsemseg:1: 0.5772952054914602
# INFO:ptsemseg:2: 0.7733361041812322
# INFO:ptsemseg:3: 0.058885984223078336
# INFO:ptsemseg:4: 0.08179483365561009
# INFO:ptsemseg:5: 0.22112648435739737
# INFO:ptsemseg:6: 0.0569620785689645
# INFO:ptsemseg:7: 0.21725335192635656
# INFO:ptsemseg:8: 0.8145541488586276
# INFO:ptsemseg:9: 0.1695567189660696
# INFO:ptsemseg:10: 0.7817562280535699
# INFO:ptsemseg:11: 0.3488158975296497
# INFO:ptsemseg:12: 0.011998868476057268
# INFO:ptsemseg:13: 0.7725509885919686
# INFO:ptsemseg:14: 0.03353451376953515
# INFO:ptsemseg:15: 0.28482105090804893
# INFO:ptsemseg:16: 0.13189924303981526
# INFO:ptsemseg:17: 0.0390534537569212
# INFO:ptsemseg:18: 0.32989508948250024
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1600/5062]  Loss: 0.2753  Time/Image: 0.1423
# INFO:ptsemseg:Iter [1600/5062]  Loss: 0.2753  Time/Image: 0.1423
# WARN: resizing labels yielded fewer classes
# Iter [1700/5062]  Loss: 0.3057  Time/Image: 0.1293
# INFO:ptsemseg:Iter [1700/5062]  Loss: 0.3057  Time/Image: 0.1293
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1800/5062]  Loss: 0.4597  Time/Image: 0.1403
# INFO:ptsemseg:Iter [1800/5062]  Loss: 0.4597  Time/Image: 0.1403
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1900/5062]  Loss: 0.2902  Time/Image: 0.1334
# INFO:ptsemseg:Iter [1900/5062]  Loss: 0.2902  Time/Image: 0.1334
# Iter [2000/5062]  Loss: 0.2255  Time/Image: 0.1362
# INFO:ptsemseg:Iter [2000/5062]  Loss: 0.2255  Time/Image: 0.1362
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.09it/s]
# INFO:ptsemseg:Iter 2000 Loss: 0.3494
# Overall Acc: 	 0.8869521047682589
# INFO:ptsemseg:Overall Acc: 	: 0.8869521047682589
# Mean Acc : 	 0.5037591724375069
# INFO:ptsemseg:Mean Acc : 	: 0.5037591724375069
# FreqW Acc : 	 0.8119502979461511
# INFO:ptsemseg:FreqW Acc : 	: 0.8119502979461511
# Mean IoU : 	 0.4090906122889306
# INFO:ptsemseg:Mean IoU : 	: 0.4090906122889306
# INFO:ptsemseg:0: 0.9374310346544918
# INFO:ptsemseg:1: 0.6110365246257861
# INFO:ptsemseg:2: 0.7983401310012953
# INFO:ptsemseg:3: 0.10916746861321637
# INFO:ptsemseg:4: 0.22555232482493107
# INFO:ptsemseg:5: 0.3293831669096713
# INFO:ptsemseg:6: 0.12835366602027543
# INFO:ptsemseg:7: 0.2853264853673599
# INFO:ptsemseg:8: 0.8418867132012295
# INFO:ptsemseg:9: 0.4218451609708594
# INFO:ptsemseg:10: 0.8916763163902197
# INFO:ptsemseg:11: 0.4116249506319115
# INFO:ptsemseg:12: 0.04191956650067356
# INFO:ptsemseg:13: 0.8034468152905161
# INFO:ptsemseg:14: 0.1694153936545241
# INFO:ptsemseg:15: 0.13105749725790128
# INFO:ptsemseg:16: 0.1520295611637191
# INFO:ptsemseg:17: 0.05045580657946889
# INFO:ptsemseg:18: 0.4327730498316322
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2100/5062]  Loss: 0.2187  Time/Image: 0.1375
# INFO:ptsemseg:Iter [2100/5062]  Loss: 0.2187  Time/Image: 0.1375
# Iter [2200/5062]  Loss: 0.3250  Time/Image: 0.1321
# INFO:ptsemseg:Iter [2200/5062]  Loss: 0.3250  Time/Image: 0.1321
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2300/5062]  Loss: 0.2533  Time/Image: 0.1399
# INFO:ptsemseg:Iter [2300/5062]  Loss: 0.2533  Time/Image: 0.1399
# Iter [2400/5062]  Loss: 0.2560  Time/Image: 0.1303
# INFO:ptsemseg:Iter [2400/5062]  Loss: 0.2560  Time/Image: 0.1303
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2500/5062]  Loss: 0.1772  Time/Image: 0.1417
# INFO:ptsemseg:Iter [2500/5062]  Loss: 0.1772  Time/Image: 0.1417
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 2500 Loss: 0.3587
# Overall Acc: 	 0.886336804307246
# INFO:ptsemseg:Overall Acc: 	: 0.886336804307246
# Mean Acc : 	 0.5209361819279126
# INFO:ptsemseg:Mean Acc : 	: 0.5209361819279126
# FreqW Acc : 	 0.8185596785830763
# INFO:ptsemseg:FreqW Acc : 	: 0.8185596785830763
# Mean IoU : 	 0.42607014837556995
# INFO:ptsemseg:Mean IoU : 	: 0.42607014837556995
# INFO:ptsemseg:0: 0.9475158971165044
# INFO:ptsemseg:1: 0.6373885441027679
# INFO:ptsemseg:2: 0.7934161450623923
# INFO:ptsemseg:3: 0.20931301175337294
# INFO:ptsemseg:4: 0.17558773600132443
# INFO:ptsemseg:5: 0.2683118681382975
# INFO:ptsemseg:6: 0.14494016307206734
# INFO:ptsemseg:7: 0.35091104705189874
# INFO:ptsemseg:8: 0.8588074653985018
# INFO:ptsemseg:9: 0.40643700050542425
# INFO:ptsemseg:10: 0.8141719417996027
# INFO:ptsemseg:11: 0.4136466192125221
# INFO:ptsemseg:12: 0.08662446881221955
# INFO:ptsemseg:13: 0.823049475895646
# INFO:ptsemseg:14: 0.22554353642197003
# INFO:ptsemseg:15: 0.34057646705186867
# INFO:ptsemseg:16: 0.11911574320869461
# INFO:ptsemseg:17: 0.041829019145306345
# INFO:ptsemseg:18: 0.4381466693854462
# Iter [2600/5062]  Loss: 0.1916  Time/Image: 0.1275
# INFO:ptsemseg:Iter [2600/5062]  Loss: 0.1916  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2700/5062]  Loss: 0.1614  Time/Image: 0.1421
# INFO:ptsemseg:Iter [2700/5062]  Loss: 0.1614  Time/Image: 0.1421
# Iter [2800/5062]  Loss: 0.1892  Time/Image: 0.1275
# INFO:ptsemseg:Iter [2800/5062]  Loss: 0.1892  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2900/5062]  Loss: 0.1543  Time/Image: 0.1413
# INFO:ptsemseg:Iter [2900/5062]  Loss: 0.1543  Time/Image: 0.1413
# Iter [3000/5062]  Loss: 0.2236  Time/Image: 0.1275
# INFO:ptsemseg:Iter [3000/5062]  Loss: 0.2236  Time/Image: 0.1275
# 1it [00:34, 34.58s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 3000 Loss: 0.3059
# Overall Acc: 	 0.9030552102092813
# INFO:ptsemseg:Overall Acc: 	: 0.9030552102092813
# Mean Acc : 	 0.5387973867881396
# INFO:ptsemseg:Mean Acc : 	: 0.5387973867881396
# FreqW Acc : 	 0.8334485687333377
# INFO:ptsemseg:FreqW Acc : 	: 0.8334485687333377
# Mean IoU : 	 0.45578449664784126
# INFO:ptsemseg:Mean IoU : 	: 0.45578449664784126
# INFO:ptsemseg:0: 0.9483005406310633
# INFO:ptsemseg:1: 0.6510587245134442
# INFO:ptsemseg:2: 0.830742037577249
# INFO:ptsemseg:3: 0.28474547789660676
# INFO:ptsemseg:4: 0.2765163504306252
# INFO:ptsemseg:5: 0.3419254566112972
# INFO:ptsemseg:6: 0.2783660690886167
# INFO:ptsemseg:7: 0.3023491861312688
# INFO:ptsemseg:8: 0.8600556309591856
# INFO:ptsemseg:9: 0.38586145661579485
# INFO:ptsemseg:10: 0.8759188530595701
# INFO:ptsemseg:11: 0.4995369236455126
# INFO:ptsemseg:12: 0.12077790609806521
# INFO:ptsemseg:13: 0.823548380488665
# INFO:ptsemseg:14: 0.14939135959850242
# INFO:ptsemseg:15: 0.29509249743062693
# INFO:ptsemseg:16: 0.12386447336115886
# INFO:ptsemseg:17: 0.13966101694915253
# INFO:ptsemseg:18: 0.47219309522257963
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3100/5062]  Loss: 0.1496  Time/Image: 0.1425
# INFO:ptsemseg:Iter [3100/5062]  Loss: 0.1496  Time/Image: 0.1425
# Iter [3200/5062]  Loss: 0.1962  Time/Image: 0.1280
# INFO:ptsemseg:Iter [3200/5062]  Loss: 0.1962  Time/Image: 0.1280
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3300/5062]  Loss: 0.1876  Time/Image: 0.1419
# INFO:ptsemseg:Iter [3300/5062]  Loss: 0.1876  Time/Image: 0.1419
# WARN: resizing labels yielded fewer classes
# Iter [3400/5062]  Loss: 0.1624  Time/Image: 0.1318
# INFO:ptsemseg:Iter [3400/5062]  Loss: 0.1624  Time/Image: 0.1318
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3500/5062]  Loss: 0.1827  Time/Image: 0.1374
# INFO:ptsemseg:Iter [3500/5062]  Loss: 0.1827  Time/Image: 0.1374
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.09it/s]
# INFO:ptsemseg:Iter 3500 Loss: 0.2795
# Overall Acc: 	 0.9159559663295047
# INFO:ptsemseg:Overall Acc: 	: 0.9159559663295047
# Mean Acc : 	 0.5928030966168091
# INFO:ptsemseg:Mean Acc : 	: 0.5928030966168091
# FreqW Acc : 	 0.8534713313354882
# INFO:ptsemseg:FreqW Acc : 	: 0.8534713313354882
# Mean IoU : 	 0.5049746441157335
# INFO:ptsemseg:Mean IoU : 	: 0.5049746441157335
# INFO:ptsemseg:0: 0.9571861699478884
# INFO:ptsemseg:1: 0.6933001080956848
# INFO:ptsemseg:2: 0.8531174642410934
# INFO:ptsemseg:3: 0.2409676142280516
# INFO:ptsemseg:4: 0.2788348699312058
# INFO:ptsemseg:5: 0.3911297293049935
# INFO:ptsemseg:6: 0.2848338220544662
# INFO:ptsemseg:7: 0.42759877941288743
# INFO:ptsemseg:8: 0.873880175329966
# INFO:ptsemseg:9: 0.4802142515599616
# INFO:ptsemseg:10: 0.9146715093702388
# INFO:ptsemseg:11: 0.5542335356874469
# INFO:ptsemseg:12: 0.21705839997942758
# INFO:ptsemseg:13: 0.8411643679287572
# INFO:ptsemseg:14: 0.3431192007615184
# INFO:ptsemseg:15: 0.46209836356742984
# INFO:ptsemseg:16: 0.1106381884346831
# INFO:ptsemseg:17: 0.1338800303720577
# INFO:ptsemseg:18: 0.5365916579911776
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3600/5062]  Loss: 0.1617  Time/Image: 0.1358
# INFO:ptsemseg:Iter [3600/5062]  Loss: 0.1617  Time/Image: 0.1358
# WARN: resizing labels yielded fewer classes
# Iter [3700/5062]  Loss: 0.1388  Time/Image: 0.1336
# INFO:ptsemseg:Iter [3700/5062]  Loss: 0.1388  Time/Image: 0.1336
# Iter [3800/5062]  Loss: 0.2203  Time/Image: 0.1394
# INFO:ptsemseg:Iter [3800/5062]  Loss: 0.2203  Time/Image: 0.1394
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3900/5062]  Loss: 0.2477  Time/Image: 0.1309
# INFO:ptsemseg:Iter [3900/5062]  Loss: 0.2477  Time/Image: 0.1309
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4000/5062]  Loss: 0.1688  Time/Image: 0.1418
# INFO:ptsemseg:Iter [4000/5062]  Loss: 0.1688  Time/Image: 0.1418
# WARN: resizing labels yielded fewer classes
# 1it [00:35, 35.26s/it]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 4000 Loss: 0.2846
# Overall Acc: 	 0.9123294124106164
# INFO:ptsemseg:Overall Acc: 	: 0.9123294124106164
# Mean Acc : 	 0.5687342014357846
# INFO:ptsemseg:Mean Acc : 	: 0.5687342014357846
# FreqW Acc : 	 0.8464338387415902
# INFO:ptsemseg:FreqW Acc : 	: 0.8464338387415902
# Mean IoU : 	 0.48642371491884345
# INFO:ptsemseg:Mean IoU : 	: 0.48642371491884345
# INFO:ptsemseg:0: 0.9620849746155584
# INFO:ptsemseg:1: 0.7196932605550455
# INFO:ptsemseg:2: 0.8380633634924953
# INFO:ptsemseg:3: 0.3243672249422226
# INFO:ptsemseg:4: 0.2994652406417112
# INFO:ptsemseg:5: 0.35038567573908963
# INFO:ptsemseg:6: 0.18827544467233784
# INFO:ptsemseg:7: 0.3635874790607313
# INFO:ptsemseg:8: 0.8433234015597899
# INFO:ptsemseg:9: 0.5058640762391315
# INFO:ptsemseg:10: 0.9094748517133754
# INFO:ptsemseg:11: 0.538179320725945
# INFO:ptsemseg:12: 0.13817501388767067
# INFO:ptsemseg:13: 0.8434069022458385
# INFO:ptsemseg:14: 0.21151804118345166
# INFO:ptsemseg:15: 0.33843383608365746
# INFO:ptsemseg:16: 0.21173106587907747
# INFO:ptsemseg:17: 0.16840072937895528
# INFO:ptsemseg:18: 0.4876206808419421
# Iter [4100/5062]  Loss: 0.1723  Time/Image: 0.1276
# INFO:ptsemseg:Iter [4100/5062]  Loss: 0.1723  Time/Image: 0.1276
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4200/5062]  Loss: 0.1071  Time/Image: 0.1426
# INFO:ptsemseg:Iter [4200/5062]  Loss: 0.1071  Time/Image: 0.1426
# Iter [4300/5062]  Loss: 0.1362  Time/Image: 0.1275
# INFO:ptsemseg:Iter [4300/5062]  Loss: 0.1362  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4400/5062]  Loss: 0.1354  Time/Image: 0.1422
# INFO:ptsemseg:Iter [4400/5062]  Loss: 0.1354  Time/Image: 0.1422
# Iter [4500/5062]  Loss: 0.1120  Time/Image: 0.1275
# INFO:ptsemseg:Iter [4500/5062]  Loss: 0.1120  Time/Image: 0.1275
# 1it [00:34, 34.67s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 4500 Loss: 0.2806
# Overall Acc: 	 0.9189228380301355
# INFO:ptsemseg:Overall Acc: 	: 0.9189228380301355
# Mean Acc : 	 0.5910585878030359
# INFO:ptsemseg:Mean Acc : 	: 0.5910585878030359
# FreqW Acc : 	 0.8584625355822231
# INFO:ptsemseg:FreqW Acc : 	: 0.8584625355822231
# Mean IoU : 	 0.5110312109539468
# INFO:ptsemseg:Mean IoU : 	: 0.5110312109539468
# INFO:ptsemseg:0: 0.9622316571970546
# INFO:ptsemseg:1: 0.7153354627362664
# INFO:ptsemseg:2: 0.853709304474166
# INFO:ptsemseg:3: 0.30155687872760145
# INFO:ptsemseg:4: 0.30397298283585844
# INFO:ptsemseg:5: 0.3713631375242946
# INFO:ptsemseg:6: 0.28948104847486084
# INFO:ptsemseg:7: 0.4353531528119674
# INFO:ptsemseg:8: 0.8748069655444496
# INFO:ptsemseg:9: 0.4610706829752747
# INFO:ptsemseg:10: 0.9139337620604197
# INFO:ptsemseg:11: 0.547255810031444
# INFO:ptsemseg:12: 0.23290297417183958
# INFO:ptsemseg:13: 0.863474394424101
# INFO:ptsemseg:14: 0.3284367600411026
# INFO:ptsemseg:15: 0.48281514187198665
# INFO:ptsemseg:16: 0.1788886043533931
# INFO:ptsemseg:17: 0.06816529665045015
# INFO:ptsemseg:18: 0.5248389912184549
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4600/5062]  Loss: 0.1188  Time/Image: 0.1414
# INFO:ptsemseg:Iter [4600/5062]  Loss: 0.1188  Time/Image: 0.1414
# Iter [4700/5062]  Loss: 0.1367  Time/Image: 0.1275
# INFO:ptsemseg:Iter [4700/5062]  Loss: 0.1367  Time/Image: 0.1275
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4800/5062]  Loss: 0.1120  Time/Image: 0.1431
# INFO:ptsemseg:Iter [4800/5062]  Loss: 0.1120  Time/Image: 0.1431
# WARN: resizing labels yielded fewer classes
# Iter [4900/5062]  Loss: 0.1274  Time/Image: 0.1303
# INFO:ptsemseg:Iter [4900/5062]  Loss: 0.1274  Time/Image: 0.1303
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [5000/5062]  Loss: 0.1136  Time/Image: 0.1393
# INFO:ptsemseg:Iter [5000/5062]  Loss: 0.1136  Time/Image: 0.1393
# 1it [00:34, 34.51s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 5000 Loss: 0.2810
# Overall Acc: 	 0.9210602516146041
# INFO:ptsemseg:Overall Acc: 	: 0.9210602516146041
# Mean Acc : 	 0.6360902223395019
# INFO:ptsemseg:Mean Acc : 	: 0.6360902223395019
# FreqW Acc : 	 0.8638717220535006
# INFO:ptsemseg:FreqW Acc : 	: 0.8638717220535006
# Mean IoU : 	 0.5310060491313431
# INFO:ptsemseg:Mean IoU : 	: 0.5310060491313431
# INFO:ptsemseg:0: 0.9644440305872417
# INFO:ptsemseg:1: 0.7269806278053526
# INFO:ptsemseg:2: 0.8609986557372753
# INFO:ptsemseg:3: 0.2844975032171305
# INFO:ptsemseg:4: 0.32026455443914253
# INFO:ptsemseg:5: 0.4365666169840047
# INFO:ptsemseg:6: 0.3530850330221878
# INFO:ptsemseg:7: 0.451145589635392
# INFO:ptsemseg:8: 0.8711563451664726
# INFO:ptsemseg:9: 0.4774780593749243
# INFO:ptsemseg:10: 0.9152090522884757
# INFO:ptsemseg:11: 0.5850213060552167
# INFO:ptsemseg:12: 0.2871216002166911
# INFO:ptsemseg:13: 0.8738102815956598
# INFO:ptsemseg:14: 0.3620355618713894
# INFO:ptsemseg:15: 0.4684167259563456
# INFO:ptsemseg:16: 0.08153470487524207
# INFO:ptsemseg:17: 0.20609277354498648
# INFO:ptsemseg:18: 0.5632559111223858
# 2it [00:35, 14.76s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.12it/s]
# INFO:ptsemseg:Iter 5062 Loss: 0.2853
# Overall Acc: 	 0.9195000621483947
# INFO:ptsemseg:Overall Acc: 	: 0.9195000621483947
# Mean Acc : 	 0.6092204850780415
# INFO:ptsemseg:Mean Acc : 	: 0.6092204850780415
# FreqW Acc : 	 0.8608796491516058
# INFO:ptsemseg:FreqW Acc : 	: 0.8608796491516058
# Mean IoU : 	 0.5141794427752812
# INFO:ptsemseg:Mean IoU : 	: 0.5141794427752812
# INFO:ptsemseg:0: 0.9604984313530475
# INFO:ptsemseg:1: 0.7157049150307352
# INFO:ptsemseg:2: 0.8584574894357749
# INFO:ptsemseg:3: 0.22935236783164287
# INFO:ptsemseg:4: 0.3180912032540394
# INFO:ptsemseg:5: 0.3880863796368716
# INFO:ptsemseg:6: 0.28273265791950397
# INFO:ptsemseg:7: 0.4759255327869714
# INFO:ptsemseg:8: 0.877964947671807
# INFO:ptsemseg:9: 0.5227589156075343
# INFO:ptsemseg:10: 0.921587926670889
# INFO:ptsemseg:11: 0.5758096582892205
# INFO:ptsemseg:12: 0.26748567366785553
# INFO:ptsemseg:13: 0.8687906916384881
# INFO:ptsemseg:14: 0.2935848702426205
# INFO:ptsemseg:15: 0.41019387927412104
# INFO:ptsemseg:16: 0.13259592391036934
# INFO:ptsemseg:17: 0.11538015762633287
# INFO:ptsemseg:18: 0.554407790882516

# %%
# N=2000
#6750
#19980

# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/19980
# Found 2000 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7ff648344c20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/6750]  Loss: 0.3326  Time/Image: 0.1330
# INFO:ptsemseg:Iter [1000/6750]  Loss: 0.3326  Time/Image: 0.1330
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2000/6750]  Loss: 0.2610  Time/Image: 0.1335
# INFO:ptsemseg:Iter [2000/6750]  Loss: 0.2610  Time/Image: 0.1335
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3000/6750]  Loss: 0.2518  Time/Image: 0.1334
# INFO:ptsemseg:Iter [3000/6750]  Loss: 0.2518  Time/Image: 0.1334
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4000/6750]  Loss: 0.1967  Time/Image: 0.1334
# INFO:ptsemseg:Iter [4000/6750]  Loss: 0.1967  Time/Image: 0.1334
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [5000/6750]  Loss: 0.1541  Time/Image: 0.1335
# INFO:ptsemseg:Iter [5000/6750]  Loss: 0.1541  Time/Image: 0.1335
# 1it [00:36, 36.23s/it]WARN: resizing labels yielded fewer classes
# 63it [00:58,  1.08it/s]
# INFO:ptsemseg:Iter 5000 Loss: 0.2750
# Overall Acc: 	 0.9172366099471989
# INFO:ptsemseg:Overall Acc: 	: 0.9172366099471989
# Mean Acc : 	 0.584440393244942
# INFO:ptsemseg:Mean Acc : 	: 0.584440393244942
# FreqW Acc : 	 0.8566781130863252
# INFO:ptsemseg:FreqW Acc : 	: 0.8566781130863252
# Mean IoU : 	 0.49955638175808287
# INFO:ptsemseg:Mean IoU : 	: 0.49955638175808287
# INFO:ptsemseg:0: 0.9633571703929251
# INFO:ptsemseg:1: 0.717967246059487
# INFO:ptsemseg:2: 0.8484127705481722
# INFO:ptsemseg:3: 0.3018073238809707
# INFO:ptsemseg:4: 0.34458828491462773
# INFO:ptsemseg:5: 0.3906390262612414
# INFO:ptsemseg:6: 0.22053392767085847
# INFO:ptsemseg:7: 0.46743220931443275
# INFO:ptsemseg:8: 0.8775245453990008
# INFO:ptsemseg:9: 0.47249637900566965
# INFO:ptsemseg:10: 0.8853109431083002
# INFO:ptsemseg:11: 0.5392988944934884
# INFO:ptsemseg:12: 0.2385052939851318
# INFO:ptsemseg:13: 0.8554241859533884
# INFO:ptsemseg:14: 0.21962439713086407
# INFO:ptsemseg:15: 0.3484250263011325
# INFO:ptsemseg:16: 0.14600927432976077
# INFO:ptsemseg:17: 0.13544752917078168
# INFO:ptsemseg:18: 0.5187668254833409
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [6000/6750]  Loss: 0.1696  Time/Image: 0.1334
# INFO:ptsemseg:Iter [6000/6750]  Loss: 0.1696  Time/Image: 0.1334
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 1it [00:34, 34.62s/it]WARN: resizing labels yielded fewer classes
# 63it [00:56,  1.11it/s]
# INFO:ptsemseg:Iter 6750 Loss: 0.2440
# Overall Acc: 	 0.9296925208169253
# INFO:ptsemseg:Overall Acc: 	: 0.9296925208169253
# Mean Acc : 	 0.6583251712450449
# INFO:ptsemseg:Mean Acc : 	: 0.6583251712450449
# FreqW Acc : 	 0.8753819662331531
# INFO:ptsemseg:FreqW Acc : 	: 0.8753819662331531
# Mean IoU : 	 0.5727425355441058
# INFO:ptsemseg:Mean IoU : 	: 0.5727425355441058
# INFO:ptsemseg:0: 0.9674325203392473
# INFO:ptsemseg:1: 0.7576155355382309
# INFO:ptsemseg:2: 0.8686691166722208
# INFO:ptsemseg:3: 0.34392077778192726
# INFO:ptsemseg:4: 0.3703204631971493
# INFO:ptsemseg:5: 0.46454250282872855
# INFO:ptsemseg:6: 0.3308345469159087
# INFO:ptsemseg:7: 0.5556892302289739
# INFO:ptsemseg:8: 0.8844930563856916
# INFO:ptsemseg:9: 0.5432087004567429
# INFO:ptsemseg:10: 0.9197623670891449
# INFO:ptsemseg:11: 0.6276673608218798
# INFO:ptsemseg:12: 0.29587099755634755
# INFO:ptsemseg:13: 0.8864803132914795
# INFO:ptsemseg:14: 0.4826119783695541
# INFO:ptsemseg:15: 0.4379792568341249
# INFO:ptsemseg:16: 0.3403378605484943
# INFO:ptsemseg:17: 0.21578011759879667
# INFO:ptsemseg:18: 0.5888914728833665

# %%
# N=2500
#8437
#83770
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/83770
# Found 2500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7fb559e38c20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/8437]  Loss: 0.3557  Time/Image: 0.1378
# INFO:ptsemseg:Iter [1000/8437]  Loss: 0.3557  Time/Image: 0.1378
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2000/8437]  Loss: 0.2863  Time/Image: 0.1354
# INFO:ptsemseg:Iter [2000/8437]  Loss: 0.2863  Time/Image: 0.1354
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3000/8437]  Loss: 0.1608  Time/Image: 0.1351
# INFO:ptsemseg:Iter [3000/8437]  Loss: 0.1608  Time/Image: 0.1351
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4000/8437]  Loss: 0.2298  Time/Image: 0.1346
# INFO:ptsemseg:Iter [4000/8437]  Loss: 0.2298  Time/Image: 0.1346
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [5000/8437]  Loss: 0.1699  Time/Image: 0.1350
# INFO:ptsemseg:Iter [5000/8437]  Loss: 0.1699  Time/Image: 0.1350
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:03,  1.00s/it]
# INFO:ptsemseg:Iter 5000 Loss: 0.2686
# Overall Acc: 	 0.9170766753730157
# INFO:ptsemseg:Overall Acc: 	: 0.9170766753730157
# Mean Acc : 	 0.6093916218972367
# INFO:ptsemseg:Mean Acc : 	: 0.6093916218972367
# FreqW Acc : 	 0.8552812252262963
# INFO:ptsemseg:FreqW Acc : 	: 0.8552812252262963
# Mean IoU : 	 0.5120477044966278
# INFO:ptsemseg:Mean IoU : 	: 0.5120477044966278
# INFO:ptsemseg:0: 0.9607367122946251
# INFO:ptsemseg:1: 0.7011818430948346
# INFO:ptsemseg:2: 0.845158347095506
# INFO:ptsemseg:3: 0.31636508109791345
# INFO:ptsemseg:4: 0.3218828799759621
# INFO:ptsemseg:5: 0.4187471316261767
# INFO:ptsemseg:6: 0.30545484264019734
# INFO:ptsemseg:7: 0.4642645374758407
# INFO:ptsemseg:8: 0.8710722949898397
# INFO:ptsemseg:9: 0.5006404357450195
# INFO:ptsemseg:10: 0.8939244705451447
# INFO:ptsemseg:11: 0.5705754010335842
# INFO:ptsemseg:12: 0.2226305879071065
# INFO:ptsemseg:13: 0.8648905655022929
# INFO:ptsemseg:14: 0.16438759487045276
# INFO:ptsemseg:15: 0.4200639601522591
# INFO:ptsemseg:16: 0.23132044195289403
# INFO:ptsemseg:17: 0.11686143572621036
# INFO:ptsemseg:18: 0.5387478217100672
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [6000/8437]  Loss: 0.1720  Time/Image: 0.1370
# INFO:ptsemseg:Iter [6000/8437]  Loss: 0.1720  Time/Image: 0.1370
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [7000/8437]  Loss: 0.1272  Time/Image: 0.1355
# INFO:ptsemseg:Iter [7000/8437]  Loss: 0.1272  Time/Image: 0.1355
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [8000/8437]  Loss: 0.1046  Time/Image: 0.1348
# INFO:ptsemseg:Iter [8000/8437]  Loss: 0.1046  Time/Image: 0.1348
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:03,  1.01s/it]
# INFO:ptsemseg:Iter 8437 Loss: 0.2319
# Overall Acc: 	 0.9326027657150437
# INFO:ptsemseg:Overall Acc: 	: 0.9326027657150437
# Mean Acc : 	 0.670513872631797
# INFO:ptsemseg:Mean Acc : 	: 0.670513872631797
# FreqW Acc : 	 0.8806686307736202
# INFO:ptsemseg:FreqW Acc : 	: 0.8806686307736202
# Mean IoU : 	 0.5826195525344247
# INFO:ptsemseg:Mean IoU : 	: 0.5826195525344247
# INFO:ptsemseg:0: 0.9686176154493868
# INFO:ptsemseg:1: 0.7525234343550521
# INFO:ptsemseg:2: 0.8804168289339191
# INFO:ptsemseg:3: 0.35481432009778596
# INFO:ptsemseg:4: 0.3937461535264202
# INFO:ptsemseg:5: 0.47952422540418055
# INFO:ptsemseg:6: 0.3622670744138634
# INFO:ptsemseg:7: 0.5758766532825259
# INFO:ptsemseg:8: 0.8917228503587764
# INFO:ptsemseg:9: 0.5120131198444641
# INFO:ptsemseg:10: 0.9261233458411539
# INFO:ptsemseg:11: 0.6444559642413298
# INFO:ptsemseg:12: 0.36274253893674413
# INFO:ptsemseg:13: 0.8895900889396109
# INFO:ptsemseg:14: 0.4154302144759052
# INFO:ptsemseg:15: 0.5067942878010341
# INFO:ptsemseg:16: 0.30179617834394906
# INFO:ptsemseg:17: 0.25925995036480004
# INFO:ptsemseg:18: 0.5920566535431666
# Exception ignored in: <function _DataLoaderIter.__del__ at 0x7fb55b83d7a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/usr/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/local/lib/python3.7/dist-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/usr/lib/python3.7/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/usr/lib/python3.7/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 498, in Client
#     answer_challenge(c, authkey)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 747, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
# Look for Model file created 
# !find  -name *.pkl
# Out:
# ./runs/config/93486/frrnB_cityscapes_best_model.pkl
# ./runs/config/63835/segnet_cityscapes_best_model.pkl
# ./runs/config/73610/frrnA_cityscapes_best_model.pkl
# ./runs/config/38233/frrnA_cityscapes_best_model.pkl
# ./runs/config/32716/frrnA_cityscapes_best_model.pkl
# ./runs/config/4180/frrnA_cityscapes_best_model.pkl
# ./runs/config/22804/frrnA_cityscapes_best_model.pkl
# ./runs/config/91429/frrnB_cityscapes_best_model.pkl
# ./runs/config/68178/frrnB_cityscapes_best_model.pkl
# ./runs/config/69218/frrnA_cityscapes_best_model.pkl
# ./runs/config/86556/frrnA_cityscapes_best_model.pkl
# ./runs/config/31811/frrnA_cityscapes_best_model.pkl
# ./runs/config/32514/frrnA_cityscapes_best_model.pkl
# ./runs/config/53520/frrnA_cityscapes_best_model.pkl
# ./runs/config/6855/frrnA_cityscapes_best_model.pkl
# ./runs/config/93453/frrnA_cityscapes_best_model.pkl
# ./runs/config/99538/frrnA_cityscapes_best_model.pkl
# ./runs/config/44415/frrnA_cityscapes_best_model.pkl
# ./runs/config/36656/frrnA_cityscapes_best_model.pkl
# ./runs/config/92826/frrnA_cityscapes_best_model.pkl
# ./runs/config/72040/frrnA_cityscapes_best_model.pkl
# ./runs/config/25588/frrnB_cityscapes_best_model.pkl
# ./runs/config/13355/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/79011/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/39740/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/78195/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/66797/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/3305/frrnB_cityscapes_best_model.pkl
# ./runs/configR/40770/frrnB_cityscapes_best_model.pkl
# ./runs/configR/62376/frrnB_cityscapes_best_model.pkl
# ./runs/configR/81899/frrnB_cityscapes_best_model.pkl
# ./runs/configR/80878/frrnB_cityscapes_best_model.pkl
# ./runs/configR/39507/frrnB_cityscapes_best_model.pkl
# ./runs/configR/32216/frrnB_cityscapes_best_model.pkl
# ./runs/configR/61329/frrnB_cityscapes_best_model.pkl
# ./runs/configR/22508/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59925/frrnB_cityscapes_best_model.pkl
# ./runs/configR/60567/frrnB_cityscapes_best_model.pkl
# ./runs/configR/50680/frrnB_cityscapes_best_model.pkl
# ./runs/configR/83673/frrnB_cityscapes_best_model.pkl
# ./runs/configR/94116/frrnB_cityscapes_best_model.pkl
# ./runs/configR/70496/frrnB_cityscapes_best_model.pkl
# ./runs/configR/79653/frrnB_cityscapes_best_model.pkl
# ./runs/configR/79032/frrnB_cityscapes_best_model.pkl
# ./runs/configR/75435/frrnB_cityscapes_best_model.pkl
# ./runs/configR/38929/frrnB_cityscapes_best_model.pkl
# ./runs/configR/41230/frrnB_cityscapes_best_model.pkl
# ./runs/configR/97147/frrnB_cityscapes_best_model.pkl
# ./runs/configR/13892/frrnB_cityscapes_best_model.pkl
# ./runs/configR/67320/frrnB_cityscapes_best_model.pkl
# ./runs/configR/82364/frrnB_cityscapes_best_model.pkl
# ./runs/configR/67976/frrnB_cityscapes_best_model.pkl
# ./runs/configR/16754/frrnB_cityscapes_best_model.pkl
# ./runs/configR/66592/frrnB_cityscapes_best_model.pkl
# ./runs/configR/68445/frrnB_cityscapes_best_model.pkl
# ./runs/configR/40951/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59187/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59472/frrnB_cityscapes_best_model.pkl
# ./runs/configR/15459/frrnB_cityscapes_best_model.pkl
# ./runs/configR/54052/frrnB_cityscapes_best_model.pkl
# ./runs/configR/75999/frrnB_cityscapes_best_model.pkl
# ./runs/configR/82837/frrnB_cityscapes_best_model.pkl
# ./runs/configU/41041/frrnB_cityscapes_best_model.pkl
# ./runs/configU/44582/frrnB_cityscapes_best_model.pkl
# ./runs/configU/78816/frrnB_cityscapes_best_model.pkl
# ./runs/configU/48417/frrnB_cityscapes_best_model.pkl
# ./runs/configU/67520/frrnB_cityscapes_best_model.pkl
# ./runs/configU/98284/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64251/frrnB_cityscapes_best_model.pkl
# ./runs/configU/58501/frrnB_cityscapes_best_model.pkl
# ./runs/configU/99099/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64916/frrnB_cityscapes_best_model.pkl
# ./runs/configU/58092/frrnB_cityscapes_best_model.pkl
# ./runs/configU/1850/frrnB_cityscapes_best_model.pkl
# ./runs/configU/75990/frrnB_cityscapes_best_model.pkl
# ./runs/configU/46987/frrnB_cityscapes_best_model.pkl
# ./runs/configU/85643/frrnB_cityscapes_best_model.pkl
# ./runs/configU/92118/frrnB_cityscapes_best_model.pkl
# ./runs/configU/85770/frrnB_cityscapes_best_model.pkl
# ./runs/configU/43431/frrnB_cityscapes_best_model.pkl
# ./runs/configU/51925/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64860/frrnB_cityscapes_best_model.pkl
# ./runs/configU/5811/frrnB_cityscapes_best_model.pkl
# ./runs/configU/37094/frrnB_cityscapes_best_model.pkl
# ./runs/configU/94599/frrnB_cityscapes_best_model.pkl
# ./runs/configU/17785/frrnB_cityscapes_best_model.pkl
# ./runs/configU/7126/frrnB_cityscapes_best_model.pkl
# ./runs/configD/9444/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59910/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59612/frrnB_cityscapes_best_model.pkl
# ./runs/configD/19940/frrnB_cityscapes_best_model.pkl
# ./runs/configD/9520/frrnB_cityscapes_best_model.pkl
# ./runs/configD/27002/frrnB_cityscapes_best_model.pkl
# ./runs/configD/25534/frrnB_cityscapes_best_model.pkl
# ./runs/configD/50564/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59329/frrnB_cityscapes_best_model.pkl
# ./runs/configD/53062/frrnB_cityscapes_best_model.pkl
# ./runs/configD/23830/frrnB_cityscapes_best_model.pkl
# ./runs/configD/22908/frrnB_cityscapes_best_model.pkl
# ./runs/configD/8872/frrnB_cityscapes_best_model.pkl
# ./runs/configD/8440/frrnB_cityscapes_best_model.pkl
# ./runs/configD/61347/frrnB_cityscapes_best_model.pkl
# ./runs/configD/77102/frrnB_cityscapes_best_model.pkl
# ./runs/configD/61725/frrnB_cityscapes_best_model.pkl
# ./runs/configD/19980/frrnB_cityscapes_best_model.pkl
# ./runs/configD/56996/frrnB_cityscapes_best_model.pkl
# ./runs/configD/63202/frrnB_cityscapes_best_model.pkl
# ./runs/configD/83770/frrnB_cityscapes_best_model.pkl
# ./runs/configD/29571/frrnB_cityscapes_best_model.pkl
# ./runs/configD/95540/frrnB_cityscapes_best_model.pkl
# ./runs/configD/58025/frrnB_cityscapes_best_model.pkl

# %% [markdown]
# #Validation set inference
# val data is indicated in the yml file
# this is actuall unseen data to the model , so its a test set

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2/pytorch-semseg/")

# %%
#n=100 diverse 
# !python validate.py --config 'configs/configR.yml' --model_path  ./runs/configD/29571/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.15436 fps
# Inference time                   (iter     2): 7.22734 fps
# Inference time                   (iter     3): 8.63617 fps
# Inference time                   (iter     4): 10.55533 fps
# Inference time                   (iter     5): 9.11223 fps
# Inference time                   (iter     6): 9.91954 fps
# Inference time                   (iter     7): 7.79544 fps
# Inference time                   (iter     8): 8.68999 fps
# Inference time                   (iter     9): 10.23060 fps
# Inference time                   (iter    10): 10.20383 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 9.14678 fps
# Inference time                   (iter    12): 9.52764 fps
# Inference time                   (iter    13): 10.62899 fps
# Inference time                   (iter    14): 9.88626 fps
# Inference time                   (iter    15): 10.56512 fps
# Inference time                   (iter    16): 9.97933 fps
# Inference time                   (iter    17): 9.16583 fps
# Inference time                   (iter    18): 10.64928 fps
# Inference time                   (iter    19): 10.80470 fps
# Inference time                   (iter    20): 10.92385 fps
# Inference time                   (iter    21): 10.70299 fps
# Inference time                   (iter    22): 10.42915 fps
# Inference time                   (iter    23): 9.89767 fps
# Inference time                   (iter    24): 10.58847 fps
# Inference time                   (iter    25): 9.30520 fps
# Inference time                   (iter    26): 10.75204 fps
# Inference time                   (iter    27): 9.83097 fps
# Inference time                   (iter    28): 10.18480 fps
# Inference time                   (iter    29): 9.91695 fps
# Inference time                   (iter    30): 10.60351 fps
# Inference time                   (iter    31): 10.28623 fps
# Inference time                   (iter    32): 9.79600 fps
# Inference time                   (iter    33): 9.82925 fps
# Inference time                   (iter    34): 10.49282 fps
# Inference time                   (iter    35): 9.87096 fps
# Inference time                   (iter    36): 10.00125 fps
# Inference time                   (iter    37): 10.24572 fps
# Inference time                   (iter    38): 10.54394 fps
# Inference time                   (iter    39): 9.24759 fps
# Inference time                   (iter    40): 10.52838 fps
# Inference time                   (iter    41): 8.74874 fps
# Inference time                   (iter    42): 10.26959 fps
# Inference time                   (iter    43): 10.63162 fps
# Inference time                   (iter    44): 10.36009 fps
# Inference time                   (iter    45): 9.75948 fps
# Inference time                   (iter    46): 10.65710 fps
# Inference time                   (iter    47): 10.45870 fps
# Inference time                   (iter    48): 10.92537 fps
# Inference time                   (iter    49): 11.72449 fps
# Inference time                   (iter    50): 11.78613 fps
# Inference time                   (iter    51): 11.76104 fps
# Inference time                   (iter    52): 11.75473 fps
# Inference time                   (iter    53): 11.72244 fps
# Inference time                   (iter    54): 11.72283 fps
# Inference time                   (iter    55): 11.87407 fps
# Inference time                   (iter    56): 11.79448 fps
# Inference time                   (iter    57): 11.81093 fps
# Inference time                   (iter    58): 11.91224 fps
# Inference time                   (iter    59): 11.79393 fps
# Inference time                   (iter    60): 11.81155 fps
# Inference time                   (iter    61): 11.77320 fps
# Inference time                   (iter    62): 11.79741 fps
# Inference time                   (iter    63): 1.10158 fps
# Overall Acc: 	 0.8099926048984083
# Mean Acc : 	 0.32376479512779877
# FreqW Acc : 	 0.6983700707831941
# Mean IoU : 	 0.2611331602746742
# 0 0.8868386458917471
# 1 0.4038878053067888
# 2 0.6593141332589428
# 3 0.10235586269431832
# 4 0.02405080169338978
# 5 0.05975084639910594
# 6 0.0013178635106850306
# 7 0.025652173913043478
# 8 0.7122329543138933
# 9 0.2741603236934177
# 10 0.8037776457314247
# 11 0.20788149890377253
# 12 0.0004100733307603242
# 13 0.6085281607005665
# 14 0.0
# 15 0.007895949034842994
# 16 0.002643799400008219
# 17 0.017928051896992335
# 18 0.1629034555451101

# %%
#n=200
# !python validate.py --config 'configs/configR.yml' --model_path ./runs/configD/95540/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.05731 fps
# Inference time                   (iter     2): 8.02679 fps
# Inference time                   (iter     3): 8.33903 fps
# Inference time                   (iter     4): 10.59212 fps
# Inference time                   (iter     5): 9.24853 fps
# Inference time                   (iter     6): 8.58508 fps
# Inference time                   (iter     7): 7.29022 fps
# Inference time                   (iter     8): 9.68446 fps
# Inference time                   (iter     9): 9.18845 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 9.48535 fps
# Inference time                   (iter    11): 9.49487 fps
# Inference time                   (iter    12): 10.67254 fps
# Inference time                   (iter    13): 9.91287 fps
# Inference time                   (iter    14): 10.69045 fps
# Inference time                   (iter    15): 9.68314 fps
# Inference time                   (iter    16): 10.34234 fps
# Inference time                   (iter    17): 10.46105 fps
# Inference time                   (iter    18): 10.11445 fps
# Inference time                   (iter    19): 10.10390 fps
# Inference time                   (iter    20): 10.63413 fps
# Inference time                   (iter    21): 9.11838 fps
# Inference time                   (iter    22): 8.99499 fps
# Inference time                   (iter    23): 9.55462 fps
# Inference time                   (iter    24): 10.22434 fps
# Inference time                   (iter    25): 9.38673 fps
# Inference time                   (iter    26): 10.21810 fps
# Inference time                   (iter    27): 8.98396 fps
# Inference time                   (iter    28): 9.83208 fps
# Inference time                   (iter    29): 9.64632 fps
# Inference time                   (iter    30): 10.51525 fps
# Inference time                   (iter    31): 9.29118 fps
# Inference time                   (iter    32): 10.10561 fps
# Inference time                   (iter    33): 10.56044 fps
# Inference time                   (iter    34): 10.65246 fps
# Inference time                   (iter    35): 10.69398 fps
# Inference time                   (iter    36): 10.70303 fps
# Inference time                   (iter    37): 10.33518 fps
# Inference time                   (iter    38): 10.23830 fps
# Inference time                   (iter    39): 9.91526 fps
# Inference time                   (iter    40): 10.57277 fps
# Inference time                   (iter    41): 8.93646 fps
# Inference time                   (iter    42): 10.79553 fps
# Inference time                   (iter    43): 9.78297 fps
# Inference time                   (iter    44): 10.33325 fps
# Inference time                   (iter    45): 9.08275 fps
# Inference time                   (iter    46): 9.45299 fps
# Inference time                   (iter    47): 10.55774 fps
# Inference time                   (iter    48): 11.09368 fps
# Inference time                   (iter    49): 10.97907 fps
# Inference time                   (iter    50): 10.97480 fps
# Inference time                   (iter    51): 11.38519 fps
# Inference time                   (iter    52): 11.87197 fps
# Inference time                   (iter    53): 11.79694 fps
# Inference time                   (iter    54): 11.77843 fps
# Inference time                   (iter    55): 11.84407 fps
# Inference time                   (iter    56): 11.84627 fps
# Inference time                   (iter    57): 11.83362 fps
# Inference time                   (iter    58): 11.74033 fps
# Inference time                   (iter    59): 11.72096 fps
# Inference time                   (iter    60): 11.81538 fps
# Inference time                   (iter    61): 11.78875 fps
# Inference time                   (iter    62): 11.70214 fps
# Inference time                   (iter    63): 1.12867 fps
# Overall Acc: 	 0.8410460745345977
# Mean Acc : 	 0.35808805088586465
# FreqW Acc : 	 0.741754638590556
# Mean IoU : 	 0.30083518915498964
# 0 0.9101466982080993
# 1 0.4847674223880843
# 2 0.7140947541869352
# 3 0.1072820901652292
# 4 0.09206210441654719
# 5 0.14295475424270923
# 6 0.012791098844229774
# 7 0.11886617515085106
# 8 0.7687350303360004
# 9 0.27188414468825084
# 10 0.8512143827313753
# 11 0.2838020801827543
# 12 4.044293098009399e-05
# 13 0.6512067059804407
# 14 0.009571958919902271
# 15 0.0
# 16 0.000914984026550045
# 17 0.046936826306453815
# 18 0.24859694023940962

# %%
#n=500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/58025/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.05726 fps
# Inference time                   (iter     2): 7.09253 fps
# Inference time                   (iter     3): 10.20403 fps
# Inference time                   (iter     4): 10.23586 fps
# Inference time                   (iter     5): 9.32859 fps
# Inference time                   (iter     6): 9.19657 fps
# Inference time                   (iter     7): 9.46145 fps
# Inference time                   (iter     8): 8.81759 fps
# Inference time                   (iter     9): 10.53676 fps
# Inference time                   (iter    10): 10.04550 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 9.48564 fps
# Inference time                   (iter    12): 9.66949 fps
# Inference time                   (iter    13): 9.70722 fps
# Inference time                   (iter    14): 10.05316 fps
# Inference time                   (iter    15): 9.79136 fps
# Inference time                   (iter    16): 10.68920 fps
# Inference time                   (iter    17): 9.76759 fps
# Inference time                   (iter    18): 10.61683 fps
# Inference time                   (iter    19): 8.87275 fps
# Inference time                   (iter    20): 10.37407 fps
# Inference time                   (iter    21): 10.42774 fps
# Inference time                   (iter    22): 10.62305 fps
# Inference time                   (iter    23): 10.64807 fps
# Inference time                   (iter    24): 9.48274 fps
# Inference time                   (iter    25): 9.75066 fps
# Inference time                   (iter    26): 10.68721 fps
# Inference time                   (iter    27): 10.24614 fps
# Inference time                   (iter    28): 10.77299 fps
# Inference time                   (iter    29): 9.06995 fps
# Inference time                   (iter    30): 9.08535 fps
# Inference time                   (iter    31): 10.19341 fps
# Inference time                   (iter    32): 10.46499 fps
# Inference time                   (iter    33): 10.17090 fps
# Inference time                   (iter    34): 10.59838 fps
# Inference time                   (iter    35): 10.85670 fps
# Inference time                   (iter    36): 10.33475 fps
# Inference time                   (iter    37): 9.78713 fps
# Inference time                   (iter    38): 9.82028 fps
# Inference time                   (iter    39): 10.42577 fps
# Inference time                   (iter    40): 10.05754 fps
# Inference time                   (iter    41): 10.70657 fps
# Inference time                   (iter    42): 9.93447 fps
# Inference time                   (iter    43): 10.62280 fps
# Inference time                   (iter    44): 9.44584 fps
# Inference time                   (iter    45): 10.10125 fps
# Inference time                   (iter    46): 10.76580 fps
# Inference time                   (iter    47): 9.89189 fps
# Inference time                   (iter    48): 10.84783 fps
# Inference time                   (iter    49): 11.76255 fps
# Inference time                   (iter    50): 11.75686 fps
# Inference time                   (iter    51): 11.73339 fps
# Inference time                   (iter    52): 11.72900 fps
# Inference time                   (iter    53): 11.70339 fps
# Inference time                   (iter    54): 11.72374 fps
# Inference time                   (iter    55): 11.66083 fps
# Inference time                   (iter    56): 11.63075 fps
# Inference time                   (iter    57): 11.71049 fps
# Inference time                   (iter    58): 11.64999 fps
# Inference time                   (iter    59): 11.84393 fps
# Inference time                   (iter    60): 11.68795 fps
# Inference time                   (iter    61): 11.77402 fps
# Inference time                   (iter    62): 11.70417 fps
# Inference time                   (iter    63): 1.10164 fps
# Overall Acc: 	 0.8865337178730422
# Mean Acc : 	 0.46958334995008705
# FreqW Acc : 	 0.8081363484144862
# Mean IoU : 	 0.39403536859042143
# 0 0.938976282721513
# 1 0.5935814676876352
# 2 0.794320411990726
# 3 0.19138423787229722
# 4 0.14656741468943796
# 5 0.29543314347531413
# 6 0.07258199324663167
# 7 0.269707029074301
# 8 0.8397930698137842
# 9 0.41258012445041936
# 10 0.8744888151100362
# 11 0.449315492376648
# 12 0.029968841918323014
# 13 0.7877037749245676
# 14 0.02602796843928411
# 15 0.2338988219333238
# 16 0.05556389029063979
# 17 0.055044364114360825
# 18 0.41973485908876507

# %%
#n=1000
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/77102/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.21946 fps
# Inference time                   (iter     2): 8.36195 fps
# Inference time                   (iter     3): 11.01944 fps
# Inference time                   (iter     4): 11.13864 fps
# Inference time                   (iter     5): 9.89255 fps
# Inference time                   (iter     6): 10.07351 fps
# Inference time                   (iter     7): 10.95755 fps
# Inference time                   (iter     8): 10.26956 fps
# Inference time                   (iter     9): 10.81015 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 11.29796 fps
# Inference time                   (iter    11): 11.19612 fps
# Inference time                   (iter    12): 11.19973 fps
# Inference time                   (iter    13): 11.28363 fps
# Inference time                   (iter    14): 11.20624 fps
# Inference time                   (iter    15): 11.43608 fps
# Inference time                   (iter    16): 11.28554 fps
# Inference time                   (iter    17): 11.23387 fps
# Inference time                   (iter    18): 11.11884 fps
# Inference time                   (iter    19): 11.05735 fps
# Inference time                   (iter    20): 11.38117 fps
# Inference time                   (iter    21): 11.23779 fps
# Inference time                   (iter    22): 11.15829 fps
# Inference time                   (iter    23): 11.01571 fps
# Inference time                   (iter    24): 11.21098 fps
# Inference time                   (iter    25): 10.92326 fps
# Inference time                   (iter    26): 11.11018 fps
# Inference time                   (iter    27): 11.23729 fps
# Inference time                   (iter    28): 11.23029 fps
# Inference time                   (iter    29): 11.23430 fps
# Inference time                   (iter    30): 11.02473 fps
# Inference time                   (iter    31): 11.20048 fps
# Inference time                   (iter    32): 11.14384 fps
# Inference time                   (iter    33): 11.12361 fps
# Inference time                   (iter    34): 11.28837 fps
# Inference time                   (iter    35): 11.32636 fps
# Inference time                   (iter    36): 11.26464 fps
# Inference time                   (iter    37): 10.84317 fps
# Inference time                   (iter    38): 11.27563 fps
# Inference time                   (iter    39): 10.96212 fps
# Inference time                   (iter    40): 11.28590 fps
# Inference time                   (iter    41): 11.07910 fps
# Inference time                   (iter    42): 11.17257 fps
# Inference time                   (iter    43): 11.18664 fps
# Inference time                   (iter    44): 11.07303 fps
# Inference time                   (iter    45): 11.19128 fps
# Inference time                   (iter    46): 11.21914 fps
# Inference time                   (iter    47): 11.25746 fps
# Inference time                   (iter    48): 11.88100 fps
# Inference time                   (iter    49): 11.99446 fps
# Inference time                   (iter    50): 12.01013 fps
# Inference time                   (iter    51): 11.98389 fps
# Inference time                   (iter    52): 11.96641 fps
# Inference time                   (iter    53): 11.97987 fps
# Inference time                   (iter    54): 11.98348 fps
# Inference time                   (iter    55): 11.99319 fps
# Inference time                   (iter    56): 11.96058 fps
# Inference time                   (iter    57): 12.00049 fps
# Inference time                   (iter    58): 11.97824 fps
# Inference time                   (iter    59): 11.98273 fps
# Inference time                   (iter    60): 11.95304 fps
# Inference time                   (iter    61): 11.93589 fps
# Inference time                   (iter    62): 11.95303 fps
# Inference time                   (iter    63): 1.11348 fps
# Overall Acc: 	 0.9065001786417984
# Mean Acc : 	 0.5623019070013162
# FreqW Acc : 	 0.8419532028097125
# Mean IoU : 	 0.47032009457778207
# 0 0.9567469818323681
# 1 0.6477808738198108
# 2 0.8383143263977103
# 3 0.23698833447119239
# 4 0.2351913107874599
# 5 0.2903040765590237
# 6 0.236529421843456
# 7 0.35436166632053107
# 8 0.8684662581714258
# 9 0.4700145725529891
# 10 0.8861723891391398
# 11 0.5171305259237122
# 12 0.2363882341223731
# 13 0.8477606323378668
# 14 0.22207611046049186
# 15 0.31200568884184937
# 16 0.18917106795431288
# 17 0.09720370530689984
# 18 0.493475620135246

# %%
#n=1500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/61725/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.27792 fps
# Inference time                   (iter     2): 7.79131 fps
# Inference time                   (iter     3): 10.58731 fps
# Inference time                   (iter     4): 10.11972 fps
# Inference time                   (iter     5): 10.69762 fps
# Inference time                   (iter     6): 9.49076 fps
# Inference time                   (iter     7): 10.64492 fps
# Inference time                   (iter     8): 10.96812 fps
# Inference time                   (iter     9): 10.41387 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 11.28327 fps
# Inference time                   (iter    11): 11.18818 fps
# Inference time                   (iter    12): 11.00381 fps
# Inference time                   (iter    13): 10.93046 fps
# Inference time                   (iter    14): 11.12689 fps
# Inference time                   (iter    15): 11.13720 fps
# Inference time                   (iter    16): 11.16268 fps
# Inference time                   (iter    17): 11.17088 fps
# Inference time                   (iter    18): 11.16206 fps
# Inference time                   (iter    19): 11.22446 fps
# Inference time                   (iter    20): 11.25279 fps
# Inference time                   (iter    21): 11.39978 fps
# Inference time                   (iter    22): 11.23354 fps
# Inference time                   (iter    23): 10.83480 fps
# Inference time                   (iter    24): 11.28122 fps
# Inference time                   (iter    25): 11.41805 fps
# Inference time                   (iter    26): 11.29041 fps
# Inference time                   (iter    27): 11.03063 fps
# Inference time                   (iter    28): 11.25787 fps
# Inference time                   (iter    29): 11.15493 fps
# Inference time                   (iter    30): 10.92356 fps
# Inference time                   (iter    31): 11.24740 fps
# Inference time                   (iter    32): 11.24373 fps
# Inference time                   (iter    33): 11.18324 fps
# Inference time                   (iter    34): 11.33941 fps
# Inference time                   (iter    35): 11.17133 fps
# Inference time                   (iter    36): 11.19076 fps
# Inference time                   (iter    37): 11.13317 fps
# Inference time                   (iter    38): 11.17892 fps
# Inference time                   (iter    39): 11.26537 fps
# Inference time                   (iter    40): 11.19571 fps
# Inference time                   (iter    41): 11.10052 fps
# Inference time                   (iter    42): 11.48201 fps
# Inference time                   (iter    43): 11.17469 fps
# Inference time                   (iter    44): 11.22750 fps
# Inference time                   (iter    45): 11.04435 fps
# Inference time                   (iter    46): 11.27011 fps
# Inference time                   (iter    47): 11.06067 fps
# Inference time                   (iter    48): 11.71908 fps
# Inference time                   (iter    49): 11.94091 fps
# Inference time                   (iter    50): 11.94589 fps
# Inference time                   (iter    51): 11.91712 fps
# Inference time                   (iter    52): 11.84181 fps
# Inference time                   (iter    53): 11.92674 fps
# Inference time                   (iter    54): 11.91607 fps
# Inference time                   (iter    55): 11.95967 fps
# Inference time                   (iter    56): 11.92242 fps
# Inference time                   (iter    57): 11.91032 fps
# Inference time                   (iter    58): 11.98887 fps
# Inference time                   (iter    59): 11.97239 fps
# Inference time                   (iter    60): 11.93071 fps
# Inference time                   (iter    61): 11.82098 fps
# Inference time                   (iter    62): 11.88759 fps
# Inference time                   (iter    63): 1.11705 fps
# Overall Acc: 	 0.9236413260070687
# Mean Acc : 	 0.6377554789029869
# FreqW Acc : 	 0.8673774253613905
# Mean IoU : 	 0.538269365273462
# 0 0.9656032425822471
# 1 0.7301935357510622
# 2 0.865447871697441
# 3 0.292529211091384
# 4 0.3349322749806974
# 5 0.45049457111340035
# 6 0.3657309125458351
# 7 0.4509266017743334
# 8 0.8750661904506383
# 9 0.4764269140266065
# 10 0.9189379799363995
# 11 0.6010998636257803
# 12 0.2990673313409141
# 13 0.8788543219776227
# 14 0.3901126151746104
# 15 0.4646271510516252
# 16 0.07708009890173079
# 17 0.21514530453518313
# 18 0.5748419476382701

# %%
#n=2000
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/19980/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.31575 fps
# Inference time                   (iter     2): 8.53821 fps
# Inference time                   (iter     3): 8.22357 fps
# Inference time                   (iter     4): 9.47286 fps
# Inference time                   (iter     5): 10.25261 fps
# Inference time                   (iter     6): 9.66656 fps
# Inference time                   (iter     7): 10.38975 fps
# Inference time                   (iter     8): 9.17525 fps
# Inference time                   (iter     9): 10.48144 fps
# Inference time                   (iter    10): 11.10719 fps
# Inference time                   (iter    11): 11.36627 fps
# Inference time                   (iter    12): 11.03431 fps
# Inference time                   (iter    13): 9.25654 fps
# Inference time                   (iter    14): 10.59837 fps
# Inference time                   (iter    15): 10.23257 fps
# Inference time                   (iter    16): 10.79507 fps
# Inference time                   (iter    17): 10.61161 fps
# Inference time                   (iter    18): 10.42242 fps
# Inference time                   (iter    19): 10.84120 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    20): 11.12966 fps
# Inference time                   (iter    21): 11.58962 fps
# Inference time                   (iter    22): 11.98159 fps
# Inference time                   (iter    23): 11.88407 fps
# Inference time                   (iter    24): 11.86273 fps
# Inference time                   (iter    25): 11.86455 fps
# Inference time                   (iter    26): 11.88178 fps
# Inference time                   (iter    27): 11.82053 fps
# Inference time                   (iter    28): 11.92979 fps
# Inference time                   (iter    29): 11.90725 fps
# Inference time                   (iter    30): 9.28271 fps
# Inference time                   (iter    31): 10.53730 fps
# Inference time                   (iter    32): 9.82176 fps
# Inference time                   (iter    33): 10.15154 fps
# Inference time                   (iter    34): 10.48839 fps
# Inference time                   (iter    35): 10.13822 fps
# Inference time                   (iter    36): 10.77080 fps
# Inference time                   (iter    37): 10.11617 fps
# Inference time                   (iter    38): 9.67237 fps
# Inference time                   (iter    39): 9.42960 fps
# Inference time                   (iter    40): 10.75080 fps
# Inference time                   (iter    41): 10.90494 fps
# Inference time                   (iter    42): 9.13789 fps
# Inference time                   (iter    43): 10.37758 fps
# Inference time                   (iter    44): 10.45812 fps
# Inference time                   (iter    45): 10.30136 fps
# Inference time                   (iter    46): 9.52688 fps
# Inference time                   (iter    47): 10.96742 fps
# Inference time                   (iter    48): 9.43957 fps
# Inference time                   (iter    49): 10.49179 fps
# Inference time                   (iter    50): 10.58305 fps
# Inference time                   (iter    51): 9.61639 fps
# Inference time                   (iter    52): 10.27835 fps
# Inference time                   (iter    53): 10.28618 fps
# Inference time                   (iter    54): 10.59863 fps
# Inference time                   (iter    55): 11.11894 fps
# Inference time                   (iter    56): 11.47076 fps
# Inference time                   (iter    57): 11.49786 fps
# Inference time                   (iter    58): 11.84303 fps
# Inference time                   (iter    59): 11.87670 fps
# Inference time                   (iter    60): 11.69076 fps
# Inference time                   (iter    61): 11.80582 fps
# Inference time                   (iter    62): 11.91707 fps
# Inference time                   (iter    63): 1.13183 fps
# Overall Acc: 	 0.9317405438291103
# Mean Acc : 	 0.6562088957094294
# FreqW Acc : 	 0.8783919045719804
# Mean IoU : 	 0.5748119534058495
# 0 0.9676718022967832
# 1 0.7578263003903167
# 2 0.8738770362418196
# 3 0.3619214841669351
# 4 0.387298015630975
# 5 0.47950880579010857
# 6 0.3368472385906449
# 7 0.5578907917385753
# 8 0.8877915145671831
# 9 0.5463777197563099
# 10 0.9246341468232803
# 11 0.6429893071430965
# 12 0.2960317065013982
# 13 0.8908553865159904
# 14 0.4660470051878635
# 15 0.4438965846911169
# 16 0.28807490318815976
# 17 0.21011142118020898
# 18 0.6017759443103754

# %%
#n=2500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/83770/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.08254 fps
# Inference time                   (iter     2): 7.75234 fps
# Inference time                   (iter     3): 8.94698 fps
# Inference time                   (iter     4): 9.30350 fps
# Inference time                   (iter     5): 9.77828 fps
# Inference time                   (iter     6): 8.51303 fps
# Inference time                   (iter     7): 8.06677 fps
# Inference time                   (iter     8): 9.60494 fps
# Inference time                   (iter     9): 10.64817 fps
# Inference time                   (iter    10): 9.32292 fps
# Inference time                   (iter    11): 8.39044 fps
# Inference time                   (iter    12): 8.62615 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    13): 7.56949 fps
# Inference time                   (iter    14): 8.24426 fps
# Inference time                   (iter    15): 8.78462 fps
# Inference time                   (iter    16): 8.74980 fps
# Inference time                   (iter    17): 8.11224 fps
# Inference time                   (iter    18): 8.34703 fps
# Inference time                   (iter    19): 8.90389 fps
# Inference time                   (iter    20): 8.98991 fps
# Inference time                   (iter    21): 9.99174 fps
# Inference time                   (iter    22): 10.00436 fps
# Inference time                   (iter    23): 10.68093 fps
# Inference time                   (iter    24): 10.17673 fps
# Inference time                   (iter    25): 10.00006 fps
# Inference time                   (iter    26): 10.63368 fps
# Inference time                   (iter    27): 10.11652 fps
# Inference time                   (iter    28): 10.31162 fps
# Inference time                   (iter    29): 9.56059 fps
# Inference time                   (iter    30): 10.24894 fps
# Inference time                   (iter    31): 10.54138 fps
# Inference time                   (iter    32): 9.51696 fps
# Inference time                   (iter    33): 10.49361 fps
# Inference time                   (iter    34): 9.19620 fps
# Inference time                   (iter    35): 10.53536 fps
# Inference time                   (iter    36): 9.71345 fps
# Inference time                   (iter    37): 10.28842 fps
# Inference time                   (iter    38): 10.67495 fps
# Inference time                   (iter    39): 10.59255 fps
# Inference time                   (iter    40): 10.16985 fps
# Inference time                   (iter    41): 9.94184 fps
# Inference time                   (iter    42): 10.13058 fps
# Inference time                   (iter    43): 10.41293 fps
# Inference time                   (iter    44): 10.25792 fps
# Inference time                   (iter    45): 10.44031 fps
# Inference time                   (iter    46): 10.00366 fps
# Inference time                   (iter    47): 10.27207 fps
# Inference time                   (iter    48): 10.79244 fps
# Inference time                   (iter    49): 11.72988 fps
# Inference time                   (iter    50): 11.67090 fps
# Inference time                   (iter    51): 11.69874 fps
# Inference time                   (iter    52): 11.60022 fps
# Inference time                   (iter    53): 11.68568 fps
# Inference time                   (iter    54): 11.67157 fps
# Inference time                   (iter    55): 11.63746 fps
# Inference time                   (iter    56): 11.69792 fps
# Inference time                   (iter    57): 11.71778 fps
# Inference time                   (iter    58): 11.65032 fps
# Inference time                   (iter    59): 11.69508 fps
# Inference time                   (iter    60): 11.70875 fps
# Inference time                   (iter    61): 11.67214 fps
# Inference time                   (iter    62): 11.72212 fps
# Inference time                   (iter    63): 1.12233 fps
# Overall Acc: 	 0.9352140956461008
# Mean Acc : 	 0.6726156903971665
# FreqW Acc : 	 0.8844426585777906
# Mean IoU : 	 0.5907063497451362
# 0 0.9694676259097392
# 1 0.7588363544460688
# 2 0.8842918104753411
# 3 0.36367399197483075
# 4 0.4003264128426186
# 5 0.4888535665008569
# 6 0.35797716906317
# 7 0.5729731829227143
# 8 0.896024395638813
# 9 0.5313722195197452
# 10 0.9302216933447979
# 11 0.6572031373935482
# 12 0.3764844621513944
# 13 0.897389396398659
# 14 0.45551031275678605
# 15 0.5287932401338051
# 16 0.30268646067724053
# 17 0.24669933698472182
# 18 0.6046358760227376

# %% [markdown]
# # Side Experiment 1
#
# Test Running the same data same settings
# N=2500
# Iters is 6750 (lower epochs than normal)

# %%
# N=2500
#8437
#
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/56996
# Found 2500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f66b12ebdd0>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/6750]  Loss: 0.2453  Time/Image: 0.1373
# INFO:ptsemseg:Iter [1000/6750]  Loss: 0.2453  Time/Image: 0.1373
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2000/6750]  Loss: 0.3443  Time/Image: 0.1355
# INFO:ptsemseg:Iter [2000/6750]  Loss: 0.3443  Time/Image: 0.1355
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3000/6750]  Loss: 0.2246  Time/Image: 0.1352
# INFO:ptsemseg:Iter [3000/6750]  Loss: 0.2246  Time/Image: 0.1352
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4000/6750]  Loss: 0.2016  Time/Image: 0.1353
# INFO:ptsemseg:Iter [4000/6750]  Loss: 0.2016  Time/Image: 0.1353
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [5000/6750]  Loss: 0.1698  Time/Image: 0.1352
# INFO:ptsemseg:Iter [5000/6750]  Loss: 0.1698  Time/Image: 0.1352
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:04,  1.02s/it]
# INFO:ptsemseg:Iter 5000 Loss: 0.3141
# Overall Acc: 	 0.903709562436284
# INFO:ptsemseg:Overall Acc: 	: 0.903709562436284
# Mean Acc : 	 0.533902819231299
# INFO:ptsemseg:Mean Acc : 	: 0.533902819231299
# FreqW Acc : 	 0.8331473931977736
# INFO:ptsemseg:FreqW Acc : 	: 0.8331473931977736
# Mean IoU : 	 0.4581468849804679
# INFO:ptsemseg:Mean IoU : 	: 0.4581468849804679
# INFO:ptsemseg:0: 0.9519052405928826
# INFO:ptsemseg:1: 0.6698426734479821
# INFO:ptsemseg:2: 0.8230839809753058
# INFO:ptsemseg:3: 0.25604519072093945
# INFO:ptsemseg:4: 0.24575070555386447
# INFO:ptsemseg:5: 0.3376781327171438
# INFO:ptsemseg:6: 0.1360309538688056
# INFO:ptsemseg:7: 0.3020503054185196
# INFO:ptsemseg:8: 0.8571637086244915
# INFO:ptsemseg:9: 0.39587254699706254
# INFO:ptsemseg:10: 0.844924750708863
# INFO:ptsemseg:11: 0.4750742037959065
# INFO:ptsemseg:12: 0.2511509376800661
# INFO:ptsemseg:13: 0.8375533629108914
# INFO:ptsemseg:14: 0.24260130222321205
# INFO:ptsemseg:15: 0.33721893683389653
# INFO:ptsemseg:16: 0.11069391969586746
# INFO:ptsemseg:17: 0.16539985952237607
# INFO:ptsemseg:18: 0.46475010234081354
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [6000/6750]  Loss: 0.1071  Time/Image: 0.1373
# INFO:ptsemseg:Iter [6000/6750]  Loss: 0.1071  Time/Image: 0.1373
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:03,  1.01s/it]
# INFO:ptsemseg:Iter 6750 Loss: 0.2535
# Overall Acc: 	 0.926521855333029
# INFO:ptsemseg:Overall Acc: 	: 0.926521855333029
# Mean Acc : 	 0.6487158334594983
# INFO:ptsemseg:Mean Acc : 	: 0.6487158334594983
# FreqW Acc : 	 0.8702296753978146
# INFO:ptsemseg:FreqW Acc : 	: 0.8702296753978146
# Mean IoU : 	 0.5564199662832966
# INFO:ptsemseg:Mean IoU : 	: 0.5564199662832966
# INFO:ptsemseg:0: 0.9671087020961407
# INFO:ptsemseg:1: 0.751936272311418
# INFO:ptsemseg:2: 0.8606772020868815
# INFO:ptsemseg:3: 0.37130951804401197
# INFO:ptsemseg:4: 0.38882598680357633
# INFO:ptsemseg:5: 0.438884654084215
# INFO:ptsemseg:6: 0.3987996977233875
# INFO:ptsemseg:7: 0.5142123136632266
# INFO:ptsemseg:8: 0.885807026124629
# INFO:ptsemseg:9: 0.5266718384755239
# INFO:ptsemseg:10: 0.8552994766575618
# INFO:ptsemseg:11: 0.6061899775171599
# INFO:ptsemseg:12: 0.2218449473153848
# INFO:ptsemseg:13: 0.8833615889899872
# INFO:ptsemseg:14: 0.4156267818251498
# INFO:ptsemseg:15: 0.5166896161897657
# INFO:ptsemseg:16: 0.22434061884567522
# INFO:ptsemseg:17: 0.1574146941905281
# INFO:ptsemseg:18: 0.5869784464384117

# %%
# N=2500 attept 2 on same data 
#8437
#
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/63202
# Found 2500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f3b691d1c20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [1000/6750]  Loss: 0.3601  Time/Image: 0.1376
# INFO:ptsemseg:Iter [1000/6750]  Loss: 0.3601  Time/Image: 0.1376
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [2000/6750]  Loss: 0.2837  Time/Image: 0.1355
# INFO:ptsemseg:Iter [2000/6750]  Loss: 0.2837  Time/Image: 0.1355
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [3000/6750]  Loss: 0.1642  Time/Image: 0.1355
# INFO:ptsemseg:Iter [3000/6750]  Loss: 0.1642  Time/Image: 0.1355
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [4000/6750]  Loss: 0.2351  Time/Image: 0.1349
# INFO:ptsemseg:Iter [4000/6750]  Loss: 0.2351  Time/Image: 0.1349
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [5000/6750]  Loss: 0.1571  Time/Image: 0.1351
# INFO:ptsemseg:Iter [5000/6750]  Loss: 0.1571  Time/Image: 0.1351
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:04,  1.03s/it]
# INFO:ptsemseg:Iter 5000 Loss: 0.2662
# Overall Acc: 	 0.9170458972862611
# INFO:ptsemseg:Overall Acc: 	: 0.9170458972862611
# Mean Acc : 	 0.63426107759324
# INFO:ptsemseg:Mean Acc : 	: 0.63426107759324
# FreqW Acc : 	 0.8559085039602443
# INFO:ptsemseg:FreqW Acc : 	: 0.8559085039602443
# Mean IoU : 	 0.5254621414271436
# INFO:ptsemseg:Mean IoU : 	: 0.5254621414271436
# INFO:ptsemseg:0: 0.9554909892819817
# INFO:ptsemseg:1: 0.6789151644869426
# INFO:ptsemseg:2: 0.8548757516193656
# INFO:ptsemseg:3: 0.3317667549516352
# INFO:ptsemseg:4: 0.32729824377748956
# INFO:ptsemseg:5: 0.434822492391989
# INFO:ptsemseg:6: 0.3609628872519649
# INFO:ptsemseg:7: 0.505615763546798
# INFO:ptsemseg:8: 0.8716674769370073
# INFO:ptsemseg:9: 0.4880070891568697
# INFO:ptsemseg:10: 0.9107542757630559
# INFO:ptsemseg:11: 0.5817926926391813
# INFO:ptsemseg:12: 0.29637486928615214
# INFO:ptsemseg:13: 0.8599819704895164
# INFO:ptsemseg:14: 0.2876553386489981
# INFO:ptsemseg:15: 0.42309542772179803
# INFO:ptsemseg:16: 0.1800905118116359
# INFO:ptsemseg:17: 0.08960255842179282
# INFO:ptsemseg:18: 0.5450104289315545
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [6000/6750]  Loss: 0.1899  Time/Image: 0.1371
# INFO:ptsemseg:Iter [6000/6750]  Loss: 0.1899  Time/Image: 0.1371
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:02,  1.01it/s]
# INFO:ptsemseg:Iter 6750 Loss: 0.2494
# Overall Acc: 	 0.9246446184785293
# INFO:ptsemseg:Overall Acc: 	: 0.9246446184785293
# Mean Acc : 	 0.6227036844645313
# INFO:ptsemseg:Mean Acc : 	: 0.6227036844645313
# FreqW Acc : 	 0.8662418278429994
# INFO:ptsemseg:FreqW Acc : 	: 0.8662418278429994
# Mean IoU : 	 0.5435907492971083
# INFO:ptsemseg:Mean IoU : 	: 0.5435907492971083
# INFO:ptsemseg:0: 0.9666350903542456
# INFO:ptsemseg:1: 0.7434322251447438
# INFO:ptsemseg:2: 0.8548263888249992
# INFO:ptsemseg:3: 0.3628936297228508
# INFO:ptsemseg:4: 0.3297025423120742
# INFO:ptsemseg:5: 0.4174560153298863
# INFO:ptsemseg:6: 0.3010786229088342
# INFO:ptsemseg:7: 0.510942463406127
# INFO:ptsemseg:8: 0.8798645052590827
# INFO:ptsemseg:9: 0.4946188653723316
# INFO:ptsemseg:10: 0.9205719936199007
# INFO:ptsemseg:11: 0.5798910303166779
# INFO:ptsemseg:12: 0.20950598302025536
# INFO:ptsemseg:13: 0.8648691744511899
# INFO:ptsemseg:14: 0.3573307992630876
# INFO:ptsemseg:15: 0.5183841098627076
# INFO:ptsemseg:16: 0.3188245379865655
# INFO:ptsemseg:17: 0.14379328198822083
# INFO:ptsemseg:18: 0.553602977501277

# %%
#n=2500

# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/56996/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.07331 fps
# Inference time                   (iter     2): 7.52851 fps
# Inference time                   (iter     3): 10.69970 fps
# Inference time                   (iter     4): 10.56079 fps
# Inference time                   (iter     5): 9.64499 fps
# Inference time                   (iter     6): 8.44012 fps
# Inference time                   (iter     7): 9.47887 fps
# Inference time                   (iter     8): 8.80902 fps
# Inference time                   (iter     9): 9.15353 fps
# Inference time                   (iter    10): 9.64360 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 10.30910 fps
# Inference time                   (iter    12): 10.44469 fps
# Inference time                   (iter    13): 9.67806 fps
# Inference time                   (iter    14): 10.33742 fps
# Inference time                   (iter    15): 9.83448 fps
# Inference time                   (iter    16): 8.54164 fps
# Inference time                   (iter    17): 10.29935 fps
# Inference time                   (iter    18): 9.14243 fps
# Inference time                   (iter    19): 10.20274 fps
# Inference time                   (iter    20): 10.55590 fps
# Inference time                   (iter    21): 9.80347 fps
# Inference time                   (iter    22): 10.81262 fps
# Inference time                   (iter    23): 10.65651 fps
# Inference time                   (iter    24): 10.45318 fps
# Inference time                   (iter    25): 9.72328 fps
# Inference time                   (iter    26): 10.30449 fps
# Inference time                   (iter    27): 10.18410 fps
# Inference time                   (iter    28): 10.84323 fps
# Inference time                   (iter    29): 9.88900 fps
# Inference time                   (iter    30): 9.40652 fps
# Inference time                   (iter    31): 10.77246 fps
# Inference time                   (iter    32): 9.51807 fps
# Inference time                   (iter    33): 10.77776 fps
# Inference time                   (iter    34): 9.52209 fps
# Inference time                   (iter    35): 10.03232 fps
# Inference time                   (iter    36): 9.27050 fps
# Inference time                   (iter    37): 10.16359 fps
# Inference time                   (iter    38): 10.15080 fps
# Inference time                   (iter    39): 10.52185 fps
# Inference time                   (iter    40): 10.32700 fps
# Inference time                   (iter    41): 9.55077 fps
# Inference time                   (iter    42): 10.36808 fps
# Inference time                   (iter    43): 9.35770 fps
# Inference time                   (iter    44): 10.42782 fps
# Inference time                   (iter    45): 10.33390 fps
# Inference time                   (iter    46): 10.21661 fps
# Inference time                   (iter    47): 10.84098 fps
# Inference time                   (iter    48): 10.70510 fps
# Inference time                   (iter    49): 11.75700 fps
# Inference time                   (iter    50): 11.77319 fps
# Inference time                   (iter    51): 11.82559 fps
# Inference time                   (iter    52): 11.76530 fps
# Inference time                   (iter    53): 11.82367 fps
# Inference time                   (iter    54): 11.73470 fps
# Inference time                   (iter    55): 11.66620 fps
# Inference time                   (iter    56): 11.74737 fps
# Inference time                   (iter    57): 11.82274 fps
# Inference time                   (iter    58): 11.79524 fps
# Inference time                   (iter    59): 11.81196 fps
# Inference time                   (iter    60): 11.88268 fps
# Inference time                   (iter    61): 11.76162 fps
# Inference time                   (iter    62): 11.73747 fps
# Inference time                   (iter    63): 1.12662 fps
# Overall Acc: 	 0.9286169947711741
# Mean Acc : 	 0.6503417250658039
# FreqW Acc : 	 0.8731227964247719
# Mean IoU : 	 0.5631794325771127
# 0 0.9674823502820359
# 1 0.7485114733063435
# 2 0.8640153014277465
# 3 0.4046803805821974
# 4 0.39840521818782726
# 5 0.4474250473601845
# 6 0.4142305362011512
# 7 0.529261924328065
# 8 0.8902198174135052
# 9 0.5266259433506713
# 10 0.8576338633139631
# 11 0.6168399321978402
# 12 0.21761033115894599
# 13 0.8907289042151654
# 14 0.46061885344207243
# 15 0.5192330897196322
# 16 0.1992315913364629
# 17 0.1521007556675063
# 18 0.5955539054738235

# %%
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/63202/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.12869 fps
# Inference time                   (iter     2): 7.78854 fps
# Inference time                   (iter     3): 7.89725 fps
# Inference time                   (iter     4): 9.83276 fps
# Inference time                   (iter     5): 8.18415 fps
# Inference time                   (iter     6): 8.19518 fps
# Inference time                   (iter     7): 8.18223 fps
# Inference time                   (iter     8): 9.95092 fps
# Inference time                   (iter     9): 10.35556 fps
# Inference time                   (iter    10): 10.44877 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 9.52629 fps
# Inference time                   (iter    12): 10.17522 fps
# Inference time                   (iter    13): 10.12966 fps
# Inference time                   (iter    14): 10.59405 fps
# Inference time                   (iter    15): 9.62529 fps
# Inference time                   (iter    16): 10.16959 fps
# Inference time                   (iter    17): 10.47521 fps
# Inference time                   (iter    18): 10.14522 fps
# Inference time                   (iter    19): 10.85226 fps
# Inference time                   (iter    20): 9.90144 fps
# Inference time                   (iter    21): 10.06798 fps
# Inference time                   (iter    22): 8.85921 fps
# Inference time                   (iter    23): 10.51098 fps
# Inference time                   (iter    24): 9.76530 fps
# Inference time                   (iter    25): 9.25998 fps
# Inference time                   (iter    26): 9.79526 fps
# Inference time                   (iter    27): 9.12819 fps
# Inference time                   (iter    28): 10.44548 fps
# Inference time                   (iter    29): 10.67510 fps
# Inference time                   (iter    30): 10.39629 fps
# Inference time                   (iter    31): 10.72522 fps
# Inference time                   (iter    32): 10.47190 fps
# Inference time                   (iter    33): 9.67481 fps
# Inference time                   (iter    34): 9.52928 fps
# Inference time                   (iter    35): 10.01111 fps
# Inference time                   (iter    36): 10.21958 fps
# Inference time                   (iter    37): 10.50986 fps
# Inference time                   (iter    38): 10.35755 fps
# Inference time                   (iter    39): 10.04318 fps
# Inference time                   (iter    40): 9.25976 fps
# Inference time                   (iter    41): 10.57703 fps
# Inference time                   (iter    42): 10.48435 fps
# Inference time                   (iter    43): 9.64642 fps
# Inference time                   (iter    44): 9.61007 fps
# Inference time                   (iter    45): 10.60767 fps
# Inference time                   (iter    46): 10.58001 fps
# Inference time                   (iter    47): 8.36780 fps
# Inference time                   (iter    48): 11.66495 fps
# Inference time                   (iter    49): 11.65602 fps
# Inference time                   (iter    50): 11.76867 fps
# Inference time                   (iter    51): 11.76868 fps
# Inference time                   (iter    52): 11.72613 fps
# Inference time                   (iter    53): 11.73304 fps
# Inference time                   (iter    54): 11.65393 fps
# Inference time                   (iter    55): 11.77896 fps
# Inference time                   (iter    56): 11.77381 fps
# Inference time                   (iter    57): 11.81944 fps
# Inference time                   (iter    58): 11.71033 fps
# Inference time                   (iter    59): 11.80032 fps
# Inference time                   (iter    60): 11.73266 fps
# Inference time                   (iter    61): 11.61087 fps
# Inference time                   (iter    62): 11.72884 fps
# Inference time                   (iter    63): 1.13466 fps
# Overall Acc: 	 0.9265428443508781
# Mean Acc : 	 0.620304933991208
# FreqW Acc : 	 0.8689764281795797
# Mean IoU : 	 0.5463859907150822
# 0 0.9682894034809532
# 1 0.7492295596370565
# 2 0.8564968220663927
# 3 0.35182727863768837
# 4 0.34544869504310155
# 5 0.41950781877768756
# 6 0.30544540492110633
# 7 0.5115000740553169
# 8 0.8831882636085013
# 9 0.4917813591630868
# 10 0.9227308994349429
# 11 0.5915762912641886
# 12 0.21706657125606565
# 13 0.871229720976218
# 14 0.38052371659199397
# 15 0.5368345750023484
# 16 0.3145612073784237
# 17 0.10669865521813246
# 18 0.5573975070733594

# %% [markdown]
# Outcome: Different results also results were below , Result is also worse than if less data was used at same iteration

# %% [markdown]
# # Side Experiment 2
#
# Test running N=100 on Iters 8437 (the max iters in this expriment. Does new data improve the model?

# %%
# N=100 (same as exp 2 n=100)
#8437 

# !python train.py --config 'configs/configD.yml'

# %%
#n=100 on 8437 iters 
# !python validate.py --config 'configs/configD.yml' --model_path

# %% [markdown]
# # TENSOR BOARD

# %%
# !pip install numpy --upgrade

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/SemSeg2/pytorch-semseg/runs/config2B

# %%
 # %reload_ext tensorboard
 # %tensorboard --logdir /content/drive/MyDrive/SemSeg2/pytorch-semseg/runs/config

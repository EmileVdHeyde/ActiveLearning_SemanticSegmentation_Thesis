# %% [markdown]
# #Semantic Segmentation Implementation 1
#
# https://github.com/meetps/pytorch-semseg

# %% [markdown]
# # Artifacts : Directory Packages and Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2")

# %%
#!cp -r '/content/drive/MyDrive/SemSeg2/data_random/leftImg8bit/val' '/content/drive/MyDrive/SemSeg2/data/leftImg8bit'

# %%
#!cp -r '/content/drive/MyDrive/SemSeg2/data_random/gtFine/val' '/content/drive/MyDrive/SemSeg2/data/gtFine'

# %% [markdown]
# matplotlib==2.0.0
# numpy==1.12.1
# scipy==0.19.0
# torch==0.4.1
# torchvision==0.2.0
# tqdm==4.11.2
# pydensecrf
# protobuf
# tensorboardX

# %%
pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org torch===0.4.1.post2 torchvision===0.2.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch===0.4.1.post2
#   Downloading torch-0.4.1.post2-cp37-cp37m-manylinux1_x86_64.whl (519.5 MB)
#      |████████████████████████████████| 519.5 MB 23 kB/s
# Collecting torchvision===0.2.0
#   Downloading torchvision-0.2.0-py2.py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.5 MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision===0.2.0) (1.19.5)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# Successfully installed torch-0.4.1.post2 torchvision-0.2.0

# %%
import torch
torch.__version__
# Out:
# '0.4.1.post2'

# %%
# !pip install numpy==1.15.0
# Out:
# Collecting numpy==1.15.0
#   Downloading numpy-1.15.0-cp37-cp37m-manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 4.1 MB/s
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# xarray 0.18.2 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 0.4.1.post2 which is incompatible.
# tifffile 2021.11.2 requires numpy>=1.15.1, but you have numpy 1.15.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pywavelets 1.2.0 requires numpy>=1.17.3, but you have numpy 1.15.0 which is incompatible.
# pyerfa 2.0.0.1 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# pyarrow 3.0.0 requires numpy>=1.16.6, but you have numpy 1.15.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# pandas 1.1.5 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# kapre 0.3.6 requires numpy>=1.18.5, but you have numpy 1.15.0 which is incompatible.
# jaxlib 0.1.71+cuda111 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# fbprophet 0.7.1 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# cupy-cuda111 9.4.0 requires numpy<1.24,>=1.17, but you have numpy 1.15.0 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.15.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.15.0

# %%
# !pip install numpy==1.12.1
# Out:
# Collecting numpy==1.12.1
#   Downloading numpy-1.12.1.zip (4.8 MB)
#      |████████████████████████████████| 4.8 MB 4.3 MB/s
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.15.0
#     Uninstalling numpy-1.15.0:
#       Successfully uninstalled numpy-1.15.0
#     Running setup.py install for numpy ... error
#   Rolling back uninstall of numpy
#   Moving to /usr/local/bin/conv-template
#    from /tmp/pip-uninstall-jj2l5ges/conv-template
#   Moving to /usr/local/bin/f2py
#    from /tmp/pip-uninstall-jj2l5ges/f2py
#   Moving to /usr/local/bin/from-template
#    from /tmp/pip-uninstall-jj2l5ges/from-template
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy-1.15.0.dist-info/
#    from /usr/local/lib/python3.7/dist-packages/~umpy-1.15.0.dist-info
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy/
#    from /usr/local/lib/python3.7/dist-packages/~umpy
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-_let8e_f/numpy_0ea63e72fe314c5db7e57bc82582b335/setup.py'"'"'; __file__='"'"'/tmp/pip-install-_let8e_f/numpy_0ea63e72fe314c5db7e57bc82582b335/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-jwijzrqx/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/numpy Check the logs for full command output.

# %%
# !pip install matplotlib==2.0.0
# Out:
# Collecting matplotlib==2.0.0
#   Downloading matplotlib-2.0.0.tar.gz (53.2 MB)
#      |████████████████████████████████| 53.2 MB 192 kB/s
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (1.15.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (2018.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (0.11.0)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from matplotlib==2.0.0) (3.0.6)
# Building wheels for collected packages: matplotlib
#   Building wheel for matplotlib (setup.py) ... done
#   Created wheel for matplotlib: filename=matplotlib-2.0.0-cp37-cp37m-linux_x86_64.whl size=10703489 sha256=166a0cf0f81ab928071c51ce4f98303594ddeafbbe38573da729989052bf5b57
#   Stored in directory: /root/.cache/pip/wheels/4c/b4/87/9b99b67a71111498af7c91a7bdd0e252112b2be41fd8873575
# Successfully built matplotlib
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires matplotlib!=3.0.0,>=2.0.2, but you have matplotlib 2.0.0 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# seaborn 0.11.2 requires matplotlib>=2.2, but you have matplotlib 2.0.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pycocotools 2.0.4 requires matplotlib>=2.1.0, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# mizani 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# fbprophet 0.7.1 requires numpy>=1.15.4, but you have numpy 1.15.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# arviz 0.11.4 requires matplotlib>=3.0, but you have matplotlib 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed matplotlib-2.0.0

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 49.6 MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.15.0)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires matplotlib!=3.0.0,>=2.0.2, but you have matplotlib 2.0.0 which is incompatible.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# seaborn 0.11.2 requires matplotlib>=2.2, but you have matplotlib 2.0.0 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.15.0 which is incompatible.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires matplotlib>=3.1.1, but you have matplotlib 2.0.0 which is incompatible.
# plotnine 0.6.0 requires numpy>=1.16.0, but you have numpy 1.15.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# kapre 0.3.6 requires numpy>=1.18.5, but you have numpy 1.15.0 which is incompatible.
# jaxlib 0.1.71+cuda111 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires numpy>=1.18, but you have numpy 1.15.0 which is incompatible.
# jax 0.2.25 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# fastai 1.0.61 requires torch>=1.0.0, but you have torch 0.4.1.post2 which is incompatible.
# arviz 0.11.4 requires matplotlib>=3.0, but you have matplotlib 2.0.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.1.0

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 4.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.4.1

# %% [markdown]
# # One Time

# %%
# !git clone https://github.com/meetps/pytorch-semseg.git

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=Emile87&password=Evangelos71!&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Out:
# --2021-11-01 16:55:09--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2021-11-01 16:55:10--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [ <=>                ]  47.36K  --.-KB/s    in 0.1s
#
# 2021-11-01 16:55:11 (373 KB/s) - ‘index.html’ saved [48495]
#
# --2021-11-01 16:55:11--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252567705 (241M) [application/octet-stream]
# Saving to: ‘gtFine_trainvaltest.zip’
#
# gtFine_trainvaltest 100%[===================>] 240.87M  24.8MB/s    in 11s
#
# 2021-11-01 16:55:22 (22.4 MB/s) - ‘gtFine_trainvaltest.zip’ saved [252567705/252567705]

# %%
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=Emile87&password=Evangelos71!&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2021-11-01 16:56:35--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2021-11-01 16:56:36--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.3’
#
# index.html.3            [ <=>                ]  47.36K  --.-KB/s    in 0.1s
#
# 2021-11-01 16:56:36 (378 KB/s) - ‘index.html.3’ saved [48495]
#
# --2021-11-01 16:56:36--  https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11592327197 (11G) [application/octet-stream]
# Saving to: ‘leftImg8bit_trainvaltest.zip’
#
# leftImg8bit_trainva 100%[===================>]  10.80G  20.1MB/s    in 9m 42s
#
# 2021-11-01 17:06:19 (19.0 MB/s) - ‘leftImg8bit_trainvaltest.zip’ saved [11592327197/11592327197]

# %%
# !mkdir data

# %%
# !unzip leftImg8bit_trainvaltest.zip -d data
# !unzip gtFine_trainvaltest.zip -d data

# %% [markdown]
#  self.class_names = [
#             0 "unlabelled",
#             1 "road",
#             2 "sidewalk",
#             3 "building",
#             4 "wall",
#             5 "fence",
#             6 "pole",
#             7 "traffic_light",
#             8 "traffic_sign",
#             9 "vegetation",
#             10 "terrain",
#             11 "sky",
#             12 "person",
#             13"rider",
#             14 "car",
#             15 "truck",
#             16 "bus",
#             17 "train",
#             18 "motorcycle",
#             19 "bicycle",
#         ]

# %% [markdown]
# # Load Config File

# %%
cd pytorch-semseg
# Out:
# [Errno 2] No such file or directory: 'pytorch-semseg'
# /content

# %%
#edit config file

# !ls /content/drive/MyDrive/SemSeg2/data
# Out:
# gtFine	leftImg8bit  license.txt  README

# %% [markdown]
# # Train Model

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2/pytorch-semseg/")

# %%
# N=100 Diverse 
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/96804
# Found 100 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7ff82533ac20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:02,  1.01it/s]
# INFO:ptsemseg:Iter 337 Loss: 0.7317
# Overall Acc: 	 0.7785908220755557
# INFO:ptsemseg:Overall Acc: 	: 0.7785908220755557
# Mean Acc : 	 0.29696590733450035
# INFO:ptsemseg:Mean Acc : 	: 0.29696590733450035
# FreqW Acc : 	 0.6547834346790861
# INFO:ptsemseg:FreqW Acc : 	: 0.6547834346790861
# Mean IoU : 	 0.23723620757246897
# INFO:ptsemseg:Mean IoU : 	: 0.23723620757246897
# INFO:ptsemseg:0: 0.8674184875167036
# INFO:ptsemseg:1: 0.29754597766803376
# INFO:ptsemseg:2: 0.6188445183784178
# INFO:ptsemseg:3: 0.025068810994043293
# INFO:ptsemseg:4: 0.004594221318247749
# INFO:ptsemseg:5: 0.08534204140742112
# INFO:ptsemseg:6: 0.0025777941447247283
# INFO:ptsemseg:7: 0.02484179293612221
# INFO:ptsemseg:8: 0.590333726146435
# INFO:ptsemseg:9: 0.18703439845371667
# INFO:ptsemseg:10: 0.7778942999717675
# INFO:ptsemseg:11: 0.2039908319542178
# INFO:ptsemseg:12: 0.0
# INFO:ptsemseg:13: 0.6294853692329232
# INFO:ptsemseg:14: 0.010563216789710731
# INFO:ptsemseg:15: 0.00017898132777298008
# INFO:ptsemseg:16: 0.0019449636079074926
# INFO:ptsemseg:17: 0.0005251107983784578
# INFO:ptsemseg:18: 0.17930340123036642

# %%
# N=200
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/4246
# Found 200 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f9af810dc20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [01:02,  1.01it/s]
# INFO:ptsemseg:Iter 675 Loss: 0.5524
# Overall Acc: 	 0.8487164370799061
# INFO:ptsemseg:Overall Acc: 	: 0.8487164370799061
# Mean Acc : 	 0.38674771141559533
# INFO:ptsemseg:Mean Acc : 	: 0.38674771141559533
# FreqW Acc : 	 0.7518127310718419
# INFO:ptsemseg:FreqW Acc : 	: 0.7518127310718419
# Mean IoU : 	 0.31846022225356446
# INFO:ptsemseg:Mean IoU : 	: 0.31846022225356446
# INFO:ptsemseg:0: 0.9198773577659439
# INFO:ptsemseg:1: 0.4907724270797443
# INFO:ptsemseg:2: 0.724246775015674
# INFO:ptsemseg:3: 0.057878224420291245
# INFO:ptsemseg:4: 0.08006199049297849
# INFO:ptsemseg:5: 0.20145900128764674
# INFO:ptsemseg:6: 0.059182263852153846
# INFO:ptsemseg:7: 0.23710384572146476
# INFO:ptsemseg:8: 0.7922519528573386
# INFO:ptsemseg:9: 0.38747030385593006
# INFO:ptsemseg:10: 0.8362620513491363
# INFO:ptsemseg:11: 0.2419607499832639
# INFO:ptsemseg:12: 0.0
# INFO:ptsemseg:13: 0.
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 5062 Loss: 0.2929
# Overall Acc: 	 0.9208657940251703
# INFO:ptsemseg:Overall Acc: 	: 0.9208657940251703
# Mean Acc : 	 0.5911962310628901
# INFO:ptsemseg:Mean Acc : 	: 0.5911962310628901
# FreqW Acc : 	 0.8606713971504575
# INFO:ptsemseg:FreqW Acc : 	: 0.8606713971504575
# Mean IoU : 	 0.5107793845609474
# INFO:ptsemseg:Mean IoU : 	: 0.5107793845609474
# INFO:ptsemseg:0: 0.9618000561006668
# INFO:ptsemseg:1: 0.7251555771315218
# INFO:ptsemseg:2: 0.8543409008422058
# INFO:ptsemseg:3: 0.2664507105720711
# INFO:ptsemseg:4: 0.27791225180996176
# INFO:ptsemseg:5: 0.3988686404826364
# INFO:ptsemseg:6: 0.32985864388842695
# INFO:ptsemseg:7: 0.5059066537751604
# INFO:ptsemseg:8: 0.8779698584181573
# INFO:ptsemseg:9: 0.4775083993048851
# INFO:ptsemseg:10: 0.925398354791099
# INFO:ptsemseg:11: 0.5795814134801429
# INFO:ptsemseg:12: 0.15194245491762204
# INFO:ptsemseg:13: 0.8682867845761764
# INFO:ptsemseg:14: 0.17978180658679907
# INFO:ptsemseg:15: 0.37862901818435657
# INFO:ptsemseg:16: 0.26739884724572016
# INFO:ptsemseg:17: 0.10983246208692761
# INFO:ptsemseg:18: 0.5681854724634613

# %%
# N=2000
#6750


# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/8440
# Found 2000 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7f974597cc20>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [100/6750]  Loss: 0.6509  Time/Image: 0.1404
# INFO:ptsemseg:Iter [100/6750]  Loss: 0.6509  Time/Image: 0.1404
# Iter [200/6750]  Loss: 0.6926  Time/Image: 0.1276
# INFO:ptsemseg:Iter [200/6750]  Loss: 0.6926  Time/Image: 0.1276
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [300/6750]  Loss: 0.5471  Time/Image: 0.1417
# INFO:ptsemseg:Iter [300/6750]  Loss: 0.5471  Time/Image: 0.1417
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [400/6750]  Loss: 0.5193  Time/Image: 0.1288
# INFO:ptsemseg:Iter [400/6750]  Loss: 0.5193  Time/Image: 0.1288
# Iter [500/6750]  Loss: 0.5687  Time/Image: 0.1275
# INFO:ptsemseg:Iter [500/6750]  Loss: 0.5687  Time/Image: 0.1275
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:58,  1.08it/s]
# INFO:ptsemseg:Iter 500 Loss: 0.7083
# Overall Acc: 	 0.804309789124644
# INFO:ptsemseg:Overall Acc: 	: 0.804309789124644
# Mean Acc : 	 0.3263948544054869
# INFO:ptsemseg:Mean Acc : 	: 0.3263948544054869
# FreqW Acc : 	 0.6916671717714101
# INFO:ptsemseg:FreqW Acc : 	: 0.6916671717714101
# Mean IoU : 	 0.24725444720925158
# INFO:ptsemseg:Mean IoU : 	: 0.24725444720925158
# INFO:ptsemseg:0: 0.9009184652159857
# INFO:ptsemseg:1: 0.35254748731940505
# INFO:ptsemseg:2: 0.6262691544326953
# INFO:ptsemseg:2: 0.8384036039921197
# INFO:ptsemseg:3: 0.26071558300036324
# INFO:ptsemseg:4: 0.31674199816873133
# INFO:ptsemseg:5: 0.41172279598333866
# INFO:ptsemseg:6: 0.28642987594631664
# INFO:ptsemseg:7: 0.39818197184685744
# INFO:ptsemseg:8: 0.854739617188558
# INFO:ptsemseg:9: 0.34174953943404957
# INFO:ptsemseg:10: 0.8775259444739001
# INFO:ptsemseg:11: 0.5285421618298903
# INFO:ptsemseg:12: 0.2279557773842108
# INFO:ptsemseg:13: 0.8020257587496036
# INFO:ptsemseg:14: 0.06589437650385732
# INFO:ptsemseg:15: 0.3168482047033571
# INFO:ptsemseg:16: 0.11449812822738312
# INFO:ptsemseg:17: 0.07235770723174974
# INFO:ptsemseg:18: 0.5244159421537402
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [6600/6750]  Loss: 0.1516  Time/Image: 0.1432
# INFO:ptsemseg:Iter [6600/6750]  Loss: 0.1516  Time/Image: 0.1432
# WARN: resizing labels yielded fewer classes
# Iter [6700/6750]  Loss: 0.1607  Time/Image: 0.1275
# INFO:ptsemseg:Iter [6700/6750]  Loss: 0.1607  Time/Image: 0.1275
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.10it/s]
# INFO:ptsemseg:Iter 6750 Loss: 0.2831
# Overall Acc: 	 0.9139408812698115
# INFO:ptsemseg:Overall Acc: 	: 0.9139408812698115
# Mean Acc : 	 0.6143345722406551
# INFO:ptsemseg:Mean Acc : 	: 0.6143345722406551
# FreqW Acc : 	 0.853529766017327
# INFO:ptsemseg:FreqW Acc : 	: 0.853529766017327
# Mean IoU : 	 0.5050473182583064
# INFO:ptsemseg:Mean IoU : 	: 0.5050473182583064
# INFO:ptsemseg:0: 0.9587028299801067
# INFO:ptsemseg:1: 0.6983554477296896
# INFO:ptsemseg:2: 0.842607036364648
# INFO:ptsemseg:3: 0.26141500646240085
# INFO:ptsemseg:4: 0.3689698366290229
# INFO:ptsemseg:5: 0.4293083053962811
# INFO:ptsemseg:6: 0.34237554968551553
# INFO:ptsemseg:7: 0.48189767727127
# INFO:ptsemseg:8: 0.8728097985058382
# INFO:ptsemseg:9: 0.44101860418377564
# INFO:ptsemseg:10: 0.9081130076772707
# INFO:ptsemseg:11: 0.5191568796795626
# INFO:ptsemseg:12: 0.28672975393460387
# INFO:ptsemseg:13: 0.8644519647343272
# INFO:ptsemseg:14: 0.20691490063458418
# INFO:ptsemseg:15: 0.3092001953147387
# INFO:ptsemseg:16: 0.16371320093949673
# INFO:ptsemseg:17: 0.0911995838519702
# INFO:ptsemseg:18: 0.5489594679327168

# %%
# N=2500
#8437
#61347
# !python train.py --config 'configs/configD.yml'
# Out:
# RUNDIR: runs/configD/61347
# Found 2500 train images
# Found 500 val images
# INFO:ptsemseg:Using cross_entropy with {} params
# INFO:ptsemseg:Using loss functools.partial(<function cross_entropy2d at 0x7fbb0bf2bdd0>)
# INFO:ptsemseg:No checkpoint found at 'content/model.pt'
# WARN: resizing labels yielded fewer classes
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='elementwise_mean' instead.
#   warnings.warn(warning.format(ret))
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [8200/8437]  Loss: 0.0987  Time/Image: 0.1407
# INFO:ptsemseg:Iter [8200/8437]  Loss: 0.0987  Time/Image: 0.1407
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# WARN: resizing labels yielded fewer classes
# Iter [8300/8437]  Loss: 0.0916  Time/Image: 0.1277
# INFO:ptsemseg:Iter [8300/8437]  Loss: 0.0916  Time/Image: 0.1277
# Iter [8400/8437]  Loss: 0.0944  Time/Image: 0.1275
# INFO:ptsemseg:Iter [8400/8437]  Loss: 0.0944  Time/Image: 0.1275
# 0it [00:00, ?it/s]WARN: resizing labels yielded fewer classes
# 63it [00:57,  1.09it/s]
# INFO:ptsemseg:Iter 8437 Loss: 0.2440
# Overall Acc: 	 0.9310564934482215
# INFO:ptsemseg:Overall Acc: 	: 0.9310564934482215
# Mean Acc : 	 0.6711749982247355
# INFO:ptsemseg:Mean Acc : 	: 0.6711749982247355
# FreqW Acc : 	 0.8769719987474454
# INFO:ptsemseg:FreqW Acc : 	: 0.8769719987474454
# Mean IoU : 	 0.5805654940779233
# INFO:ptsemseg:Mean IoU : 	: 0.5805654940779233
# INFO:ptsemseg:0: 0.9675795789580892
# INFO:ptsemseg:1: 0.7483350145444309
# INFO:ptsemseg:2: 0.8682795307348267
# INFO:ptsemseg:3: 0.41656845169228907
# INFO:ptsemseg:4: 0.35194537956501815
# INFO:ptsemseg:5: 0.4835096544367348
# INFO:ptsemseg:6: 0.4147040630044809
# INFO:ptsemseg:7: 0.5711692905010105
# INFO:ptsemseg:8: 0.8892701209572246
# INFO:ptsemseg:9: 0.5228439350315919
# INFO:ptsemseg:10: 0.9000112340509797
# INFO:ptsemseg:11: 0.6493958154519927
# INFO:ptsemseg:12: 0.38738669169448636
# INFO:ptsemseg:13: 0.8964597878841344
# INFO:ptsemseg:14: 0.4014914490511591
# INFO:ptsemseg:15: 0.5179035320926699
# INFO:ptsemseg:16: 0.17549276928619217
# INFO:ptsemseg:17: 0.258027830866674
# INFO:ptsemseg:18: 0.6103702576765614

# %%
# Look for Model file created 
# !find  -name *.pkl
# Out:
# ./runs/config/93486/frrnB_cityscapes_best_model.pkl
# ./runs/config/63835/segnet_cityscapes_best_model.pkl
# ./runs/config/73610/frrnA_cityscapes_best_model.pkl
# ./runs/config/38233/frrnA_cityscapes_best_model.pkl
# ./runs/config/32716/frrnA_cityscapes_best_model.pkl
# ./runs/config/4180/frrnA_cityscapes_best_model.pkl
# ./runs/config/22804/frrnA_cityscapes_best_model.pkl
# ./runs/config/91429/frrnB_cityscapes_best_model.pkl
# ./runs/config/68178/frrnB_cityscapes_best_model.pkl
# ./runs/config/69218/frrnA_cityscapes_best_model.pkl
# ./runs/config/86556/frrnA_cityscapes_best_model.pkl
# ./runs/config/31811/frrnA_cityscapes_best_model.pkl
# ./runs/config/32514/frrnA_cityscapes_best_model.pkl
# ./runs/config/53520/frrnA_cityscapes_best_model.pkl
# ./runs/config/6855/frrnA_cityscapes_best_model.pkl
# ./runs/config/93453/frrnA_cityscapes_best_model.pkl
# ./runs/config/99538/frrnA_cityscapes_best_model.pkl
# ./runs/config/44415/frrnA_cityscapes_best_model.pkl
# ./runs/config/36656/frrnA_cityscapes_best_model.pkl
# ./runs/config/92826/frrnA_cityscapes_best_model.pkl
# ./runs/config/72040/frrnA_cityscapes_best_model.pkl
# ./runs/config/25588/frrnB_cityscapes_best_model.pkl
# ./runs/config/13355/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/79011/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/39740/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/78195/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/66797/frrnB_cityscapes_best_model.pkl
# ./runs/config2B/3305/frrnB_cityscapes_best_model.pkl
# ./runs/configR/40770/frrnB_cityscapes_best_model.pkl
# ./runs/configR/62376/frrnB_cityscapes_best_model.pkl
# ./runs/configR/81899/frrnB_cityscapes_best_model.pkl
# ./runs/configR/80878/frrnB_cityscapes_best_model.pkl
# ./runs/configR/39507/frrnB_cityscapes_best_model.pkl
# ./runs/configR/32216/frrnB_cityscapes_best_model.pkl
# ./runs/configR/61329/frrnB_cityscapes_best_model.pkl
# ./runs/configR/22508/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59925/frrnB_cityscapes_best_model.pkl
# ./runs/configR/60567/frrnB_cityscapes_best_model.pkl
# ./runs/configR/50680/frrnB_cityscapes_best_model.pkl
# ./runs/configR/83673/frrnB_cityscapes_best_model.pkl
# ./runs/configR/94116/frrnB_cityscapes_best_model.pkl
# ./runs/configR/70496/frrnB_cityscapes_best_model.pkl
# ./runs/configR/79653/frrnB_cityscapes_best_model.pkl
# ./runs/configR/79032/frrnB_cityscapes_best_model.pkl
# ./runs/configR/75435/frrnB_cityscapes_best_model.pkl
# ./runs/configR/38929/frrnB_cityscapes_best_model.pkl
# ./runs/configR/41230/frrnB_cityscapes_best_model.pkl
# ./runs/configR/97147/frrnB_cityscapes_best_model.pkl
# ./runs/configR/13892/frrnB_cityscapes_best_model.pkl
# ./runs/configR/67320/frrnB_cityscapes_best_model.pkl
# ./runs/configR/82364/frrnB_cityscapes_best_model.pkl
# ./runs/configR/67976/frrnB_cityscapes_best_model.pkl
# ./runs/configR/16754/frrnB_cityscapes_best_model.pkl
# ./runs/configR/66592/frrnB_cityscapes_best_model.pkl
# ./runs/configR/68445/frrnB_cityscapes_best_model.pkl
# ./runs/configR/40951/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59187/frrnB_cityscapes_best_model.pkl
# ./runs/configR/59472/frrnB_cityscapes_best_model.pkl
# ./runs/configR/15459/frrnB_cityscapes_best_model.pkl
# ./runs/configR/54052/frrnB_cityscapes_best_model.pkl
# ./runs/configR/75999/frrnB_cityscapes_best_model.pkl
# ./runs/configR/82837/frrnB_cityscapes_best_model.pkl
# ./runs/configU/41041/frrnB_cityscapes_best_model.pkl
# ./runs/configU/44582/frrnB_cityscapes_best_model.pkl
# ./runs/configU/78816/frrnB_cityscapes_best_model.pkl
# ./runs/configU/48417/frrnB_cityscapes_best_model.pkl
# ./runs/configU/67520/frrnB_cityscapes_best_model.pkl
# ./runs/configU/98284/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64251/frrnB_cityscapes_best_model.pkl
# ./runs/configU/58501/frrnB_cityscapes_best_model.pkl
# ./runs/configU/99099/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64916/frrnB_cityscapes_best_model.pkl
# ./runs/configU/58092/frrnB_cityscapes_best_model.pkl
# ./runs/configU/1850/frrnB_cityscapes_best_model.pkl
# ./runs/configU/75990/frrnB_cityscapes_best_model.pkl
# ./runs/configU/46987/frrnB_cityscapes_best_model.pkl
# ./runs/configU/85643/frrnB_cityscapes_best_model.pkl
# ./runs/configU/92118/frrnB_cityscapes_best_model.pkl
# ./runs/configU/85770/frrnB_cityscapes_best_model.pkl
# ./runs/configU/43431/frrnB_cityscapes_best_model.pkl
# ./runs/configU/51925/frrnB_cityscapes_best_model.pkl
# ./runs/configU/64860/frrnB_cityscapes_best_model.pkl
# ./runs/configU/5811/frrnB_cityscapes_best_model.pkl
# ./runs/configU/37094/frrnB_cityscapes_best_model.pkl
# ./runs/configU/94599/frrnB_cityscapes_best_model.pkl
# ./runs/configU/17785/frrnB_cityscapes_best_model.pkl
# ./runs/configU/7126/frrnB_cityscapes_best_model.pkl
# ./runs/configD/9444/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59910/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59612/frrnB_cityscapes_best_model.pkl
# ./runs/configD/19940/frrnB_cityscapes_best_model.pkl
# ./runs/configD/9520/frrnB_cityscapes_best_model.pkl
# ./runs/configD/27002/frrnB_cityscapes_best_model.pkl
# ./runs/configD/25534/frrnB_cityscapes_best_model.pkl
# ./runs/configD/50564/frrnB_cityscapes_best_model.pkl
# ./runs/configD/59329/frrnB_cityscapes_best_model.pkl
# ./runs/configD/53062/frrnB_cityscapes_best_model.pkl
# ./runs/configD/23830/frrnB_cityscapes_best_model.pkl
# ./runs/configD/22908/frrnB_cityscapes_best_model.pkl
# ./runs/configD/8872/frrnB_cityscapes_best_model.pkl
# ./runs/configD/8440/frrnB_cityscapes_best_model.pkl
# ./runs/configD/61347/frrnB_cityscapes_best_model.pkl
# ./runs/configD/77102/frrnB_cityscapes_best_model.pkl
# ./runs/configD/61725/frrnB_cityscapes_best_model.pkl
# ./runs/configD/19980/frrnB_cityscapes_best_model.pkl
# ./runs/configD/56996/frrnB_cityscapes_best_model.pkl
# ./runs/configD/63202/frrnB_cityscapes_best_model.pkl
# ./runs/configD/83770/frrnB_cityscapes_best_model.pkl
# ./runs/configD/29571/frrnB_cityscapes_best_model.pkl
# ./runs/configD/95540/frrnB_cityscapes_best_model.pkl
# ./runs/configD/58025/frrnB_cityscapes_best_model.pkl
# ./runs/configD/87901/frrnB_cityscapes_best_model.pkl
# ./runs/configD/4246/frrnB_cityscapes_best_model.pkl
# ./runs/configD/96804/frrnB_cityscapes_best_model.pkl

# %% [markdown]
# #Validation set inference
# val data is indicated in the yml file
# this is actuall unseen data to the model , so its a test set

# %%
import os
os.chdir("/content/drive/MyDrive/SemSeg2/pytorch-semseg/")

# %%
#n=100 diverse 
# !python validate.py --config 'configs/configR.yml' --model_path  ./runs/configD/96804/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.08804 fps
# Inference time                   (iter     2): 7.23249 fps
# Inference time                   (iter     3): 9.87180 fps
# Inference time                   (iter     4): 10.34796 fps
# Inference time                   (iter     5): 8.37804 fps
# Inference time                   (iter     6): 9.03450 fps
# Inference time                   (iter     7): 8.62144 fps
# Inference time                   (iter     8): 9.92871 fps
# Inference time                   (iter     9): 10.19403 fps
# Inference time                   (iter    10): 10.35697 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 10.01895 fps
# Inference time                   (iter    12): 10.58923 fps
# Inference time                   (iter    13): 10.60199 fps
# Inference time                   (iter    14): 10.51167 fps
# Inference time                   (iter    15): 10.39196 fps
# Inference time                   (iter    16): 10.53258 fps
# Inference time                   (iter    17): 10.41714 fps
# Inference time                   (iter    18): 8.93692 fps
# Inference time                   (iter    19): 10.40712 fps
# Inference time                   (iter    20): 10.24603 fps
# Inference time                   (iter    21): 9.21487 fps
# Inference time                   (iter    22): 10.53215 fps
# Inference time                   (iter    23): 10.32543 fps
# Inference time                   (iter    24): 9.34297 fps
# Inference time                   (iter    25): 9.99203 fps
# Inference time                   (iter    26): 10.44341 fps
# Inference time                   (iter    27): 10.67510 fps
# Inference time                   (iter    28): 10.11424 fps
# Inference time                   (iter    29): 9.98790 fps
# Inference time                   (iter    30): 10.17852 fps
# Inference time                   (iter    31): 10.42229 fps
# Inference time                   (iter    32): 10.37607 fps
# Inference time                   (iter    33): 10.05974 fps
# Inference time                   (iter    34): 10.55266 fps
# Inference time                   (iter    35): 10.22743 fps
# Inference time                   (iter    36): 10.45930 fps
# Inference time                   (iter    37): 9.40320 fps
# Inference time                   (iter    38): 10.44969 fps
# Inference time                   (iter    39): 10.53622 fps
# Inference time                   (iter    40): 10.52635 fps
# Inference time                   (iter    41): 9.99555 fps
# Inference time                   (iter    42): 9.86260 fps
# Inference time                   (iter    43): 10.47874 fps
# Inference time                   (iter    44): 10.36451 fps
# Inference time                   (iter    45): 10.02511 fps
# Inference time                   (iter    46): 10.32023 fps
# Inference time                   (iter    47): 10.38772 fps
# Inference time                   (iter    48): 11.48068 fps
# Inference time                   (iter    49): 11.68443 fps
# Inference time                   (iter    50): 11.65883 fps
# Inference time                   (iter    51): 11.63376 fps
# Inference time                   (iter    52): 11.72974 fps
# Inference time                   (iter    53): 11.56023 fps
# Inference time                   (iter    54): 11.62750 fps
# Inference time                   (iter    55): 11.67535 fps
# Inference time                   (iter    56): 11.64678 fps
# Inference time                   (iter    57): 11.72524 fps
# Inference time                   (iter    58): 11.67120 fps
# Inference time                   (iter    59): 11.71910 fps
# Inference time                   (iter    60): 11.66490 fps
# Inference time                   (iter    61): 11.60222 fps
# Inference time                   (iter    62): 11.67649 fps
# Inference time                   (iter    63): 1.12723 fps
# Overall Acc: 	 0.7809368368863822
# Mean Acc : 	 0.29740483053353445
# FreqW Acc : 	 0.6570815738251811
# Mean IoU : 	 0.23815262440699217
# 0 0.8685478640691089
# 1 0.29485826430600853
# 2 0.6218270405119213
# 3 0.021866546438232642
# 4 0.002759132500549339
# 5 0.08544559275761554
# 6 0.0019413211524947295
# 7 0.022813560374079285
# 8 0.5947062075308321
# 9 0.18618916575864344
# 10 0.7821560660554788
# 11 0.2071001213592233
# 12 0.0
# 13 0.6365411602033211
# 14 0.015614395596108891
# 15 0.0001388329078776479
# 16 0.0013809305724044624
# 17 0.0005943284088979453
# 18 0.18041933323005288

# %%
#n=200
# !python validate.py --config 'configs/configR.yml' --model_path ./runs/configD/4246/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.11520 fps
# Inference time                   (iter     2): 6.84712 fps
# Inference time                   (iter     3): 7.35075 fps
# Inference time                   (iter     4): 10.04430 fps
# Inference time                   (iter     5): 10.12354 fps
# Inference time                   (iter     6): 9.17641 fps
# Inference time                   (iter     7): 9.27335 fps
# Inference time                   (iter     8): 9.62572 fps
# Inference time                   (iter     9): 9.91155 fps
# Inference time                   (iter    10): 8.69141 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    11): 10.17243 fps
# Inference time                   (iter    12): 10.10375 fps
# Inference time                   (iter    13): 9.99308 fps
# Inference time                   (iter    14): 10.06254 fps
# Inference time                   (iter    15): 10.32190 fps
# Inference time                   (iter    16): 10.57296 fps
# Inference time                   (iter    17): 10.14610 fps
# Inference time                   (iter    18): 9.85024 fps
# Inference time                   (iter    19): 9.75785 fps
# Inference time                   (iter    20): 10.54444 fps
# Inference time                   (iter    21): 9.13725 fps
# Inference time                   (iter    22): 10.13453 fps
# Inference time                   (iter    23): 9.85186 fps
# Inference time                   (iter    24): 10.36447 fps
# Inference time                   (iter    25): 10.27857 fps
# Inference time                   (iter    26): 10.70497 fps
# Inference time                   (iter    27): 9.84724 fps
# Inference time                   (iter    28): 10.04636 fps
# Inference time                   (iter    29): 9.47159 fps
# Inference time                   (iter    30): 9.85431 fps
# Inference time                   (iter    31): 9.79240 fps
# Inference time                   (iter    32): 10.45560 fps
# Inference time                   (iter    33): 10.48084 fps
# Inference time                   (iter    34): 10.61044 fps
# Inference time                   (iter    35): 10.56714 fps
# Inference time                   (iter    36): 10.33217 fps
# Inference time                   (iter    37): 9.82978 fps
# Inference time                   (iter    38): 9.95531 fps
# Inference time                   (iter    39): 10.07750 fps
# Inference time                   (iter    40): 10.44139 fps
# Inference time                   (iter    41): 9.89110 fps
# Inference time                   (iter    42): 10.26781 fps
# Inference time                   (iter    43): 9.46938 fps
# Inference time                   (iter    44): 9.32456 fps
# Inference time                   (iter    45): 10.68008 fps
# Inference time                   (iter    46): 10.35943 fps
# Inference time                   (iter    47): 9.66031 fps
# Inference time                   (iter    48): 11.62220 fps
# Inference time                   (iter    49): 11.74001 fps
# Inference time                   (iter    50): 11.84125 fps
# Inference time                   (iter    51): 11.87500 fps
# Inference time                   (iter    52): 11.78588 fps
# Inference time                   (iter    53): 11.78717 fps
# Inference time                   (iter    54): 11.72328 fps
# Inference time                   (iter    55): 11.81504 fps
# Inference time                   (iter    56): 11.78663 fps
# Inference time                   (iter    57): 11.77205 fps
# Inference time                   (iter    58): 11.68638 fps
# Inference time                   (iter    59): 11.80075 fps
# Inference time                   (iter    60): 11.87374 fps
# Inference time                   (iter    61): 11.66746 fps
# Inference time                   (iter    62): 11.68289 fps
# Inference time                   (iter    63): 1.12559 fps
# Overall Acc: 	 0.8512137644202391
# Mean Acc : 	 0.3838510495816195
# FreqW Acc : 	 0.7541491140983259
# Mean IoU : 	 0.3183774787398258
# 0 0.9202294200148503
# 1 0.4837073565019837
# 2 0.7308160530333829
# 3 0.058927731484078656
# 4 0.08424960264756472
# 5 0.19860319108378421
# 6 0.05459615729014762
# 7 0.23633636390188134
# 8 0.7959924343259509
# 9 0.39084004193882715
# 10 0.8402833420587431
# 11 0.24778269347703016
# 12 0.0
# 13 0.6249875217596317
# 14 0.0336925144884423
# 15 0.05767081949269138
# 16 0.0
# 17 6.156750877337001e-05
# 18 0.29039528504892675

# %%
#n=500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/87901/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.05174 fps
# Inference time                   (iter     2): 7.51193 fps
# Inference time                   (iter     3): 10.41678 fps
# Inference time                   (iter     4): 10.15393 fps
# Inference time                   (iter     5): 9.03842 fps
# Inference time                   (iter     6): 7.76928 fps
# Inference time                   (iter     7): 10.10511 fps
# Inference time                   (iter     8): 8.74905 fps
# Inference time                   (iter     9): 10.58477 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 10.52718 fps
# Inference time                   (iter    11): 10.55282 fps
# Inference time                   (iter    12): 10.49356 fps
# Inference time                   (iter    13): 10.35954 fps
# Inference time                   (iter    14): 9.89613 fps
# Inference time                   (iter    15): 10.45096 fps
# Inference time                   (iter    16): 10.25258 fps
# Inference time                   (iter    17): 10.10674 fps
# Inference time                   (iter    18): 10.41718 fps
# Inference time                   (iter    19): 10.29711 fps
# Inference time                   (iter    20): 10.29534 fps
# Inference time                   (iter    21): 10.42031 fps
# Inference time                   (iter    22): 10.10266 fps
# Inference time                   (iter    23): 10.41619 fps
# Inference time                   (iter    24): 10.67354 fps
# Inference time                   (iter    25): 10.14571 fps
# Inference time                   (iter    26): 10.46461 fps
# Inference time                   (iter    27): 9.30578 fps
# Inference time                   (iter    28): 10.28027 fps
# Inference time                   (iter    29): 10.68425 fps
# Inference time                   (iter    30): 10.44628 fps
# Inference time                   (iter    31): 10.31173 fps
# Inference time                   (iter    32): 10.31675 fps
# Inference time                   (iter    33): 10.17691 fps
# Inference time                   (iter    34): 10.42019 fps
# Inference time                   (iter    35): 9.98803 fps
# Inference time                   (iter    36): 10.38218 fps
# Inference time                   (iter    37): 10.56570 fps
# Inference time                   (iter    38): 10.27413 fps
# Inference time                   (iter    39): 10.33237 fps
# Inference time                   (iter    40): 10.53019 fps
# Inference time                   (iter    41): 10.47732 fps
# Inference time                   (iter    42): 10.17791 fps
# Inference time                   (iter    43): 9.68610 fps
# Inference time                   (iter    44): 10.33558 fps
# Inference time                   (iter    45): 10.68866 fps
# Inference time                   (iter    46): 10.52643 fps
# Inference time                   (iter    47): 10.05460 fps
# Inference time                   (iter    48): 11.61816 fps
# Inference time                   (iter    49): 11.77244 fps
# Inference time                   (iter    50): 11.74313 fps
# Inference time                   (iter    51): 11.82500 fps
# Inference time                   (iter    52): 11.80776 fps
# Inference time                   (iter    53): 11.81219 fps
# Inference time                   (iter    54): 11.74532 fps
# Inference time                   (iter    55): 11.76983 fps
# Inference time                   (iter    56): 11.69358 fps
# Inference time                   (iter    57): 11.82334 fps
# Inference time                   (iter    58): 11.69794 fps
# Inference time                   (iter    59): 11.67788 fps
# Inference time                   (iter    60): 11.72877 fps
# Inference time                   (iter    61): 11.70118 fps
# Inference time                   (iter    62): 11.69476 fps
# Inference time                   (iter    63): 1.12632 fps
# Overall Acc: 	 0.8786186111868225
# Mean Acc : 	 0.4726993509932708
# FreqW Acc : 	 0.7986483557191587
# Mean IoU : 	 0.38774433412575204
# 0 0.9405479272167293
# 1 0.5914382220493475
# 2 0.7798558967823779
# 3 0.16443930388710115
# 4 0.03520934785571788
# 5 0.3087826873545598
# 6 0.12000805254284204
# 7 0.24913282858140015
# 8 0.802217052866133
# 9 0.38198876591260494
# 10 0.88406178069726
# 11 0.42194657350417425
# 12 0.040704506951969595
# 13 0.8062717609595614
# 14 0.13069328652917947
# 15 0.14611612420926898
# 16 0.12372957559838617
# 17 0.06620922342058874
# 18 0.3737894314700888

# %%
#n=1000
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/23830/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.62362 fps
# Inference time                   (iter     2): 9.29861 fps
# Inference time                   (iter     3): 9.52587 fps
# Inference time                   (iter     4): 10.68135 fps
# Inference time                   (iter     5): 10.82741 fps
# Inference time                   (iter     6): 10.86539 fps
# Inference time                   (iter     7): 11.21431 fps
# Inference time                   (iter     8): 11.02008 fps
# Inference time                   (iter     9): 9.68822 fps
# Inference time                   (iter    10): 8.85470 fps
# Inference time                   (iter    11): 10.88751 fps
# Inference time                   (iter    12): 11.23835 fps
# Inference time                   (iter    13): 11.13768 fps
# Inference time                   (iter    14): 11.10840 fps
# Inference time                   (iter    15): 11.08227 fps
# Inference time                   (iter    16): 11.02398 fps
# Inference time                   (iter    17): 11.45988 fps
# Inference time                   (iter    18): 11.21259 fps
# Inference time                   (iter    19): 10.98808 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    20): 11.36367 fps
# Inference time                   (iter    21): 10.73475 fps
# Inference time                   (iter    22): 11.61192 fps
# Inference time                   (iter    23): 11.68242 fps
# Inference time                   (iter    24): 11.52556 fps
# Inference time                   (iter    25): 11.64688 fps
# Inference time                   (iter    26): 11.67779 fps
# Inference time                   (iter    27): 10.48791 fps
# Inference time                   (iter    28): 10.86405 fps
# Inference time                   (iter    29): 11.06433 fps
# Inference time                   (iter    30): 11.39860 fps
# Inference time                   (iter    31): 10.06516 fps
# Inference time                   (iter    32): 10.86292 fps
# Inference time                   (iter    33): 11.10523 fps
# Inference time                   (iter    34): 11.23395 fps
# Inference time                   (iter    35): 11.16721 fps
# Inference time                   (iter    36): 10.93910 fps
# Inference time                   (iter    37): 10.43261 fps
# Inference time                   (iter    38): 10.89162 fps
# Inference time                   (iter    39): 11.24161 fps
# Inference time                   (iter    40): 11.44176 fps
# Inference time                   (iter    41): 10.97565 fps
# Inference time                   (iter    42): 10.38923 fps
# Inference time                   (iter    43): 11.01928 fps
# Inference time                   (iter    44): 11.41115 fps
# Inference time                   (iter    45): 10.96507 fps
# Inference time                   (iter    46): 10.18573 fps
# Inference time                   (iter    47): 11.20737 fps
# Inference time                   (iter    48): 10.57544 fps
# Inference time                   (iter    49): 10.48390 fps
# Inference time                   (iter    50): 11.00523 fps
# Inference time                   (iter    51): 11.39320 fps
# Inference time                   (iter    52): 9.89592 fps
# Inference time                   (iter    53): 10.60151 fps
# Inference time                   (iter    54): 11.50394 fps
# Inference time                   (iter    55): 11.41286 fps
# Inference time                   (iter    56): 11.63400 fps
# Inference time                   (iter    57): 11.66087 fps
# Inference time                   (iter    58): 11.66811 fps
# Inference time                   (iter    59): 11.61802 fps
# Inference time                   (iter    60): 11.64758 fps
# Inference time                   (iter    61): 11.67536 fps
# Inference time                   (iter    62): 11.64657 fps
# Inference time                   (iter    63): 1.14008 fps
# Overall Acc: 	 0.9168215151054042
# Mean Acc : 	 0.5648412034962116
# FreqW Acc : 	 0.8533521128337617
# Mean IoU : 	 0.49315150191390195
# 0 0.9583716843100669
# 1 0.6931804379086467
# 2 0.847341172449708
# 3 0.39708770090845563
# 4 0.22927348945244486
# 5 0.4120900469614187
# 6 0.2694693419476167
# 7 0.4076810670518186
# 8 0.8760602341449168
# 9 0.48238088164430615
# 10 0.9067313899221917
# 11 0.5557222684748919
# 12 0.1275843187166092
# 13 0.8518843197846382
# 14 0.2373028209180719
# 15 0.32004687859699055
# 16 0.2311364227142756
# 17 0.032288214801597416
# 18 0.5342458456554721

# %%
#n=1500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/8872/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.23027 fps
# Inference time                   (iter     2): 7.92593 fps
# Inference time                   (iter     3): 10.91121 fps
# Inference time                   (iter     4): 11.23996 fps
# Inference time                   (iter     5): 9.44874 fps
# Inference time                   (iter     6): 8.79160 fps
# Inference time                   (iter     7): 10.25465 fps
# Inference time                   (iter     8): 10.61842 fps
# Inference time                   (iter     9): 10.62044 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 11.02704 fps
# Inference time                   (iter    11): 11.00378 fps
# Inference time                   (iter    12): 10.90901 fps
# Inference time                   (iter    13): 10.83063 fps
# Inference time                   (iter    14): 11.03739 fps
# Inference time                   (iter    15): 11.09384 fps
# Inference time                   (iter    16): 11.07935 fps
# Inference time                   (iter    17): 11.19829 fps
# Inference time                   (iter    18): 11.25729 fps
# Inference time                   (iter    19): 11.13270 fps
# Inference time                   (iter    20): 11.05828 fps
# Inference time                   (iter    21): 10.75505 fps
# Inference time                   (iter    22): 11.14341 fps
# Inference time                   (iter    23): 11.26728 fps
# Inference time                   (iter    24): 11.12063 fps
# Inference time                   (iter    25): 11.13471 fps
# Inference time                   (iter    26): 11.05436 fps
# Inference time                   (iter    27): 11.14401 fps
# Inference time                   (iter    28): 11.26521 fps
# Inference time                   (iter    29): 11.22720 fps
# Inference time                   (iter    30): 10.95946 fps
# Inference time                   (iter    31): 11.15261 fps
# Inference time                   (iter    32): 10.99424 fps
# Inference time                   (iter    33): 11.00568 fps
# Inference time                   (iter    34): 11.16105 fps
# Inference time                   (iter    35): 11.00261 fps
# Inference time                   (iter    36): 11.15546 fps
# Inference time                   (iter    37): 11.00904 fps
# Inference time                   (iter    38): 11.16625 fps
# Inference time                   (iter    39): 11.19461 fps
# Inference time                   (iter    40): 11.17137 fps
# Inference time                   (iter    41): 11.08580 fps
# Inference time                   (iter    42): 11.27508 fps
# Inference time                   (iter    43): 10.99001 fps
# Inference time                   (iter    44): 10.93394 fps
# Inference time                   (iter    45): 11.26103 fps
# Inference time                   (iter    46): 10.99102 fps
# Inference time                   (iter    47): 11.06747 fps
# Inference time                   (iter    48): 11.68298 fps
# Inference time                   (iter    49): 11.87473 fps
# Inference time                   (iter    50): 11.90881 fps
# Inference time                   (iter    51): 11.91048 fps
# Inference time                   (iter    52): 11.92952 fps
# Inference time                   (iter    53): 11.85268 fps
# Inference time                   (iter    54): 11.70969 fps
# Inference time                   (iter    55): 11.85603 fps
# Inference time                   (iter    56): 11.90354 fps
# Inference time                   (iter    57): 11.91444 fps
# Inference time                   (iter    58): 11.90442 fps
# Inference time                   (iter    59): 11.88922 fps
# Inference time                   (iter    60): 11.78851 fps
# Inference time                   (iter    61): 11.89981 fps
# Inference time                   (iter    62): 11.89109 fps
# Inference time                   (iter    63): 1.13469 fps
# Overall Acc: 	 0.9265827496121996
# Mean Acc : 	 0.6199774318319058
# FreqW Acc : 	 0.8700483142820971
# Mean IoU : 	 0.5382612258173992
# 0 0.9671482762994614
# 1 0.742491158133291
# 2 0.8651818811721613
# 3 0.3269713521878717
# 4 0.2603372545059827
# 5 0.4303013235708251
# 6 0.37645529789999316
# 7 0.4728360350861779
# 8 0.8848523053930561
# 9 0.5069778320642429
# 10 0.9205342868168823
# 11 0.6023122959472694
# 12 0.23634845175382244
# 13 0.8830327431327921
# 14 0.42917396282327586
# 15 0.3441284403669725
# 16 0.19572996973646425
# 17 0.20090726529441297
# 18 0.5812431583456285

# %%
#n=2000
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/8440/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.17752 fps
# Inference time                   (iter     2): 8.33494 fps
# Inference time                   (iter     3): 11.06039 fps
# Inference time                   (iter     4): 9.74491 fps
# Inference time                   (iter     5): 9.86571 fps
# Inference time                   (iter     6): 9.43549 fps
# Inference time                   (iter     7): 10.41573 fps
# Inference time                   (iter     8): 11.15570 fps
# Inference time                   (iter     9): 10.99343 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 11.09239 fps
# Inference time                   (iter    11): 11.11073 fps
# Inference time                   (iter    12): 11.11965 fps
# Inference time                   (iter    13): 10.96610 fps
# Inference time                   (iter    14): 11.10329 fps
# Inference time                   (iter    15): 11.05587 fps
# Inference time                   (iter    16): 11.16444 fps
# Inference time                   (iter    17): 11.09963 fps
# Inference time                   (iter    18): 11.12862 fps
# Inference time                   (iter    19): 11.07861 fps
# Inference time                   (iter    20): 11.19524 fps
# Inference time                   (iter    21): 11.20822 fps
# Inference time                   (iter    22): 10.99676 fps
# Inference time                   (iter    23): 11.25137 fps
# Inference time                   (iter    24): 11.00887 fps
# Inference time                   (iter    25): 11.12640 fps
# Inference time                   (iter    26): 10.98687 fps
# Inference time                   (iter    27): 10.87363 fps
# Inference time                   (iter    28): 11.08384 fps
# Inference time                   (iter    29): 11.04472 fps
# Inference time                   (iter    30): 11.17710 fps
# Inference time                   (iter    31): 11.12576 fps
# Inference time                   (iter    32): 11.15649 fps
# Inference time                   (iter    33): 11.19450 fps
# Inference time                   (iter    34): 11.16629 fps
# Inference time                   (iter    35): 11.17763 fps
# Inference time                   (iter    36): 11.24184 fps
# Inference time                   (iter    37): 11.01482 fps
# Inference time                   (iter    38): 11.05512 fps
# Inference time                   (iter    39): 11.22743 fps
# Inference time                   (iter    40): 11.17570 fps
# Inference time                   (iter    41): 10.88810 fps
# Inference time                   (iter    42): 11.21030 fps
# Inference time                   (iter    43): 11.50930 fps
# Inference time                   (iter    44): 11.12025 fps
# Inference time                   (iter    45): 11.02772 fps
# Inference time                   (iter    46): 11.17319 fps
# Inference time                   (iter    47): 11.03728 fps
# Inference time                   (iter    48): 11.80528 fps
# Inference time                   (iter    49): 11.73144 fps
# Inference time                   (iter    50): 11.91821 fps
# Inference time                   (iter    51): 11.88047 fps
# Inference time                   (iter    52): 11.92345 fps
# Inference time                   (iter    53): 11.91722 fps
# Inference time                   (iter    54): 11.92506 fps
# Inference time                   (iter    55): 11.91695 fps
# Inference time                   (iter    56): 11.95585 fps
# Inference time                   (iter    57): 11.93154 fps
# Inference time                   (iter    58): 11.90661 fps
# Inference time                   (iter    59): 11.94586 fps
# Inference time                   (iter    60): 11.86930 fps
# Inference time                   (iter    61): 11.83630 fps
# Inference time                   (iter    62): 11.90410 fps
# Inference time                   (iter    63): 1.10913 fps
# Overall Acc: 	 0.9259879156208736
# Mean Acc : 	 0.6354723503405465
# FreqW Acc : 	 0.8706320800246463
# Mean IoU : 	 0.5491255674327021
# 0 0.9657301494176057
# 1 0.7345877544234599
# 2 0.8669956673356322
# 3 0.2967050060989884
# 4 0.2934130498911163
# 5 0.46595307561937216
# 6 0.4003124112468049
# 7 0.488592922052044
# 8 0.8837499513128843
# 9 0.48827276906481043
# 10 0.9211487828320711
# 11 0.6264433548816012
# 12 0.25829613957801995
# 13 0.882047274421494
# 14 0.3643967885885769
# 15 0.4764611904530829
# 16 0.28704617205998423
# 17 0.1414719879934438
# 18 0.59176133395035

# %%
#n=2500
# !python validate.py --config 'configs/configD.yml' --model_path ./runs/configD/61347/frrnB_cityscapes_best_model.pkl
# Out:
# Found 500 val images
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1890: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# Inference time                   (iter     1): 2.24409 fps
# Inference time                   (iter     2): 8.27679 fps
# Inference time                   (iter     3): 10.97683 fps
# Inference time                   (iter     4): 10.52002 fps
# Inference time                   (iter     5): 10.60951 fps
# Inference time                   (iter     6): 9.32996 fps
# Inference time                   (iter     7): 10.55386 fps
# Inference time                   (iter     8): 10.67325 fps
# Inference time                   (iter     9): 10.65550 fps
# WARN: resizing labels yielded fewer classes
# Inference time                   (iter    10): 10.47502 fps
# Inference time                   (iter    11): 11.06661 fps
# Inference time                   (iter    12): 11.05295 fps
# Inference time                   (iter    13): 11.12252 fps
# Inference time                   (iter    14): 10.91955 fps
# Inference time                   (iter    15): 11.15997 fps
# Inference time                   (iter    16): 11.06203 fps
# Inference time                   (iter    17): 11.03043 fps
# Inference time                   (iter    18): 11.08537 fps
# Inference time                   (iter    19): 11.11403 fps
# Inference time                   (iter    20): 11.03215 fps
# Inference time                   (iter    21): 11.03372 fps
# Inference time                   (iter    22): 11.00391 fps
# Inference time                   (iter    23): 11.39908 fps
# Inference time                   (iter    24): 11.20590 fps
# Inference time                   (iter    25): 11.19262 fps
# Inference time                   (iter    26): 11.15096 fps
# Inference time                   (iter    27): 11.04776 fps
# Inference time                   (iter    28): 10.95391 fps
# Inference time                   (iter    29): 11.18842 fps
# Inference time                   (iter    30): 11.21712 fps
# Inference time                   (iter    31): 11.18176 fps
# Inference time                   (iter    32): 11.05576 fps
# Inference time                   (iter    33): 11.07532 fps
# Inference time                   (iter    34): 11.06162 fps
# Inference time                   (iter    35): 11.13290 fps
# Inference time                   (iter    36): 11.19532 fps
# Inference time                   (iter    37): 11.13806 fps
# Inference time                   (iter    38): 11.14569 fps
# Inference time                   (iter    39): 11.14367 fps
# Inference time                   (iter    40): 11.10882 fps
# Inference time                   (iter    41): 11.06054 fps
# Inference time                   (iter    42): 10.99101 fps
# Inference time                   (iter    43): 11.18265 fps
# Inference time                   (iter    44): 11.15981 fps
# Inference time                   (iter    45): 11.15845 fps
# Inference time                   (iter    46): 11.02493 fps
# Inference time                   (iter    47): 11.22428 fps
# Inference time                   (iter    48): 11.66712 fps
# Inference time                   (iter    49): 11.76963 fps
# Inference time                   (iter    50): 11.82899 fps
# Inference time                   (iter    51): 11.83861 fps
# Inference time                   (iter    52): 11.86616 fps
# Inference time                   (iter    53): 11.90641 fps
# Inference time                   (iter    54): 11.83074 fps
# Inference time                   (iter    55): 11.84945 fps
# Inference time                   (iter    56): 11.84894 fps
# Inference time                   (iter    57): 11.84566 fps
# Inference time                   (iter    58): 11.85982 fps
# Inference time                   (iter    59): 11.84764 fps
# Inference time                   (iter    60): 11.71566 fps
# Inference time                   (iter    61): 11.87185 fps
# Inference time                   (iter    62): 11.79775 fps
# Inference time                   (iter    63): 1.11285 fps
# Overall Acc: 	 0.9363856486257959
# Mean Acc : 	 0.693680665934731
# FreqW Acc : 	 0.8868614128999942
# Mean IoU : 	 0.6032135255581327
# 0 0.9702353292535076
# 1 0.7614593218247043
# 2 0.8843171523830182
# 3 0.4894471873493323
# 4 0.36112027549715486
# 5 0.5039431887658176
# 6 0.45339708260712547
# 7 0.5801008521298968
# 8 0.8982043754285512
# 9 0.5332840105458507
# 10 0.9318444255337796
# 11 0.6721965427038106
# 12 0.38489485354485453
# 13 0.8979453250858367
# 14 0.4750908536834971
# 15 0.5499171858979415
# 16 0.345773983820537
# 17 0.14685732579233807
# 18 0.6210277137569682

# %% [markdown]
# # TENSOR BOARD

# %%
# !pip install numpy --upgrade

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/SemSeg2/pytorch-semseg/runs/config2B

# %%
 # %reload_ext tensorboard
 # %tensorboard --logdir /content/drive/MyDrive/SemSeg2/pytorch-semseg/runs/config
